# %% [markdown]
# # Lab 2 - Spark SQL
# ![image](https://hadoopi.files.wordpress.com/2014/10/screen-shot-2014-10-25-at-14-29-50.png?w=597&h=222)
#
# This lab will show you how to work with the [SparkSQL](http://spark.apache.org/sql/) library.  It's meant to be self-guided, but don't hesitate to ask your presentor for help.
# <br>
#  <div class="panel-group" id="accordion-1">
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-1" href="#collapse1-1">
#         Hint 1</a>
#       </h4>
#     </div>
#     <div id="collapse1-1" class="panel-collapse collapse">
#       <div class="panel-body"><i>SparkSession</i> is not included by default.   You need to import it from <i>pyspark.sql</i></div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-1" href="#collapse2-1">
#         Hint 2</a>
#       </h4>
#     </div>
#     <div id="collapse2-1" class="panel-collapse collapse">
#       <div class="panel-body"><i>SparkSession</i> needs the builder method.</div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-1" href="#collapse3-1">
#         Hint 3</a>
#       </h4>
#     </div>
#     <div id="collapse3-1" class="panel-collapse collapse">
#       <div class="panel-body">Type:<br>
#
# from pyspark.sql import SparkSession<br>
# spark = SparkSession.builder.getOrCreate()<br></div>
#     </div>
#   </div>
# </div>

# %% [markdown]
# ## Step 1 - Getting started: Create a [Spark Session](http://spark.apache.org/docs/latest/sql-programming-guide.html#starting-point-sparksession)

# %%
#Import the SparkSQL library and connect to the current Spark context
# Good examples here --> http://spark.apache.org/docs/latest/sql-programming-guide.html
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()

# %% [markdown]
# ## Step 2 - Download a JSON Recordset to work with
# Let's download the data, we can run commands on the console of the server (or docker image) that the notebook environment is using. To do so we simply put a "!" in front of the command that we want to run. For example:
#
# !pwd
#
# To get the data we will download a file to the environment. Simple run these two commands, the first just ensures that the file is removed if it exists:
#
# !rm world_bank.json.gz -f <br>
# !wget https://raw.githubusercontent.com/bradenrc/sparksql_pot/master/world_bank.json.gz<br><br>
#  <div class="panel-group" id="accordion-2">
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-1" href="#collapse1-2">
#         Advanced Optional 1</a>
#       </h4>
#     </div>
#     <div id="collapse1-2" class="panel-collapse collapse">
#       <div class="panel-body">Comment out the rm statement i.e. #!rm and re-run this section.   What is the name of the downloaded file?</div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-2" href="#collapse2-2">
#         Advanced Optional 2</a>
#       </h4>
#     </div>
#     <div id="collapse2-2" class="panel-collapse collapse">
#       <div class="panel-body">Add !ls to see all the files currently in storage.   Try running !mkdir testdir</div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-2" href="#collapse3-2">
#         Advanced Optional 3</a>
#       </h4>
#     </div>
#     <div id="collapse3-2" class="panel-collapse collapse">
#       <div class="panel-body">Clean up all added files/directories.   Use !rmdir to remove a directory.</div>
#     </div>
#   </div>
# </div>

# %%
#Download file here
# !rm world_bank.json.gz -f 
# !wget https://raw.githubusercontent.com/bradenrc/sparksql_pot/master/world_bank.json.gz
# Out:
# --2016-11-23 11:18:10--  https://raw.githubusercontent.com/bradenrc/sparksql_pot/master/world_bank.json.gz
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.48.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.48.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 446287 (436K) [application/octet-stream]
# Saving to: 'world_bank.json.gz'
#
# 100%[======================================>] 446,287     --.-K/s   in 0.03s
#
# 2016-11-23 11:18:11 (16.2 MB/s) - 'world_bank.json.gz' saved [446287/446287]

# %% [markdown]
# ## Step 3 - Create a Dataframe
# <br>
# Use the SparkSession you created earlier to read the World Bank json data - <i>world_bank.json.gz</i> as a Dataframe</a><br><br>
#  <div class="panel-group" id="accordion-3">
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-3" href="#collapse1-3">
#         Hint 1</a>
#       </h4>
#     </div>
#     <div id="collapse1-3" class="panel-collapse collapse">
#       <div class="panel-body">Use the <i>read</i> function to return a Dataframe reader</div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-3" href="#collapse2-3">
#         Hint 2</a>
#       </h4>
#     </div>
#     <div id="collapse2-3" class="panel-collapse collapse">
#       <div class="panel-body">Use the <i>json()</i> method in Dataframe to read the file.   Note that the method handles a gzipped file format.</div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-3" href="#collapse3-3">
#         Hint 3</a>
#       </h4>
#     </div>
#     <div id="collapse3-3" class="panel-collapse collapse">
#       <div class="panel-body">To create the Dataframe type:<br>
#
# example1_df = spark.read.json("world_bank.json.gz")<br></div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-4" href="#collapse4-3">
#         Advanced Optional</a>
#       </h4>
#     </div>
#     <div id="collapse4-3" class="panel-collapse collapse">
#       <div class="panel-body">Obtain the same result by using <i>textFile()</i> to read the file as RDD and then convert to a Dataframe</div>
#     </div>
#   </div>
# </div>

# %%
#Create the Dataframe here:
df = spark.read.json("world_bank.json.gz")
example1_df = spark.read.json("world_bank.json.gz")
#Advanced Solution
rdd = spark.sparkContext.textFile("world_bank.json.gz")
df2 = spark.read.json(rdd)

print df.select(df['_id'],df['borrower']).show(1)
# print rdd.take(1)
#print df2.select(df['borrower']).show(1)
#print df2.show(1)
# Out:
# +--------------------+--------------------+
# |                 _id|            borrower|
# +--------------------+--------------------+
# |[52b213b38594d8a2...|FEDERAL DEMOCRATI...|
# +--------------------+--------------------+
# only showing top 1 row
#
# None

# %% [markdown]
#  ## Step 3.1 - Show the Dataframe schema
#  <br>
#  <div class="panel-group" id="accordion-31">
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-1" href="#collapse1-31">
#         Hint 1</a>
#       </h4>
#     </div>
#     <div id="collapse1-31" class="panel-collapse collapse">
#       <div class="panel-body"><h3>We can look at the schema with this command:</h3>
#
# Type: <br>
# example1_df.printSchema()</div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-31" href="#collapse2-31">
#         Advanced Optional 1</a>
#       </h4>
#     </div>
#     <div id="collapse2-31" class="panel-collapse collapse">
#       <div class="panel-body">Get the dataframe columns.   Try using command-completion (use TAB after the .) to obtain the list of possible methods/values</div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-31" href="#collapse3-31">
#         Advanced Optional 2</a>
#       </h4>
#     </div>
#     <div id="collapse3-31" class="panel-collapse collapse">
#       <div class="panel-body">Convert the dataframe back to JSON and print the first value</div>
#     </div>
#   </div>
# </div>

# %%
#Print out the schema
# !ls
#df.printSchema()
#Advanced Option 1
#print df.columns

#Advanced Option 2
df.toJSON().take(1)

# %% [markdown]
# ## Step 3.2 - Using the Dataframe
# <br>
# Dataframes are a subset of RDDs and can be similarly transformed.  You can map and filter them.
# <br>Take a look at the first two rows of data using the [take()](http://spark.apache.org/docs/latest/api/python/pyspark.sql.html?highlight=take#pyspark.sql.DataFrame.take) function.<br>
# <div class="panel-group" id="accordion-1">
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-32" href="#collapse1-32">
#         Hint 1</a>
#       </h4>
#     </div>
#     <div id="collapse1-32" class="panel-collapse collapse">
#       <div class="panel-body">example1_df.take(2)</div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-32" href="#collapse2-32">
#         Advanced Optional 1</a>
#       </h4>
#     </div>
#     <div id="collapse2-32" class="panel-collapse collapse">
#       <div class="panel-body"><i>take()</i> returns data as an RDD list of Row objects.   <i>show()</i> prints the objects to the console.   What is the default number of rows displayed?</div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-32" href="#collapse3-32">
#         Advanced Optional 2</a>
#       </h4>
#     </div>
#     <div id="collapse3-32" class="panel-collapse collapse">
#       <div class="panel-body">Save the table as a parquet table.   Use !ls to confirm it was saved.  Use a <i><a href="https://spark.apache.org/docs/1.6.2/api/python/pyspark.sql.html#pyspark.sql.DataFrameWriter"DataFrameWriter></a></i>  What did you see when you ran the ls command?</div>
#     </div>
#   </div>
# </div>

# %%
#Use take on the DataFrame to pull out 2 rows
df.take(2)

#Advanced Option 1
df.show() # defaults to 20 rows
#Advanced Option 2
# !rm -r blahblah.parquet
df.write.save("blahblah.parquet")
# !ls -l blahblah.parquet
# %ll
# !ps -ef
# Out:
# +--------------------+----------+--------------------+--------------------+--------------------+--------------------+--------------------+-----------+--------------------+------------------+--------------------+------------------------+--------+-----------+-------+----------+--------------------+--------------------+----------------+---------------+--------------------+--------------------+--------------------+--------------------+-----------+--------+--------------------+---------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------+------+------+--------------------+--------------------+--------------------+--------------+---------+------------+--------------------+
# |                 _id|approvalfy|board_approval_month|   boardapprovaldate|            borrower|         closingdate|    country_namecode|countrycode|         countryname|  countryshortname|               docty|envassesmentcategorycode|grantamt|ibrdcommamt|     id|idacommamt|           impagency|        lendinginstr|lendinginstrtype|lendprojectcost| majorsector_percent|   mjsector_namecode|             mjtheme|    mjtheme_namecode|mjthemecode|prodline|        prodlinetext|productlinetype|    project_abstract|        project_name|         projectdocs|projectfinancialtype|projectstatusdisplay|          regionname|              sector|             sector1|             sector2|             sector3|             sector4|     sector_namecode|    sectorcode|source|status|supplementprojectflg|              theme1|      theme_namecode|     themecode| totalamt|totalcommamt|                 url|
# +--------------------+----------+--------------------+--------------------+--------------------+--------------------+--------------------+-----------+--------------------+------------------+--------------------+------------------------+--------+-----------+-------+----------+--------------------+--------------------+----------------+---------------+--------------------+--------------------+--------------------+--------------------+-----------+--------+--------------------+---------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------+------+------+--------------------+--------------------+--------------------+--------------+---------+------------+--------------------+
# |[52b213b38594d8a2...|      1999|            November|2013-11-12T00:00:00Z|FEDERAL DEMOCRATI...|2018-07-07T00:00:00Z|Federal Democrati...|         ET|Federal Democrati...|          Ethiopia|Project Informati...|                       C|       0|          0|P129828| 130000000|MINISTRY OF EDUCA...|Investment Projec...|              IN|      550000000|[[Education,46], ...|[[EX,Education], ...| [Human development]|[[8,Human develop...|       8,11|      PE|            IBRD/IDA|              L|[The development ...|Ethiopia General ...|[[28-AUG-2013,PID...|                 IDA|              Active|              Africa|[[Primary educati...|[Primary educatio...|[Secondary educat...|[Public administr...|[Tertiary educati...|[[EP,Primary educ...|   ET,BS,ES,EP|  IBRD|Active|                   N|[Education for al...|[[65,Education fo...|            65|130000000|   130000000|http://www.worldb...|
# |[52b213b38594d8a2...|      2015|            November|2013-11-04T00:00:00Z|GOVERNMENT OF TUN...|                null|Republic of Tunis...|         TN| Republic of Tunisia|           Tunisia|Project Informati...|                       C| 4700000|          0|P144674|         0| MINISTRY OF FINANCE|Specific Investme...|              IN|        5700000|[[Public Administ...|[[BX,Public Admin...|[Economic managem...|[[1,Economic mana...|        1,6|      RE|Recipient Execute...|              L|                null|TN: DTF Social Pr...|[[29-MAR-2013,PID...|               OTHER|              Active|Middle East and N...|[[Public administ...|[Public administr...|[General public a...|                null|                null|[[BS,Public admin...|         BZ,BS|  IBRD|Active|                   N|[Other economic m...|[[24,Other econom...|         54,24|        0|     4700000|http://www.worldb...|
# |[52b213b38594d8a2...|      2014|            November|2013-11-01T00:00:00Z|MINISTRY OF FINAN...|                null|         Tuvalu!$!TV|         TV|              Tuvalu|            Tuvalu|Resettlement Plan...|                       B|       0|          0|P145310|   6060000|MINISTRY OF TRANS...|Investment Projec...|              IN|        6060000|[[Transportation,...|[[TX,Transportati...|[Trade and integr...|[[5,Trade and int...|   5,2,11,6|      PE|            IBRD/IDA|              L|                null|Tuvalu Aviation I...|[[21-OCT-2013,RPL...|                 IDA|              Active|East Asia and Pac...|[[Rural and Inter...|[Rural and Inter-...|                null|                null|                null|[[TI,Rural and In...|            TI|  IBRD|Active|                   Y|[Regional integra...|[[47,Regional int...|   52,81,25,47|  6060000|     6060000|http://www.worldb...|
# |[52b213b38594d8a2...|      2014|             October|2013-10-31T00:00:00Z|MIN. OF PLANNING ...|                null|Republic of Yemen...|         RY|   Republic of Yemen|Yemen, Republic of|Procurement Plan,...|                       C| 1500000|          0|P144665|         0|LABOR INTENSIVE P...|Technical Assista...|              IN|        1500000|[[Health and othe...|[[JX,Health and o...|[Social dev/gende...|[[7,Social dev/ge...|        7,7|      RE|Recipient Execute...|              L|                null|Gov't and Civil S...|[[15-MAY-2013,PRO...|               OTHER|              Active|Middle East and N...|[[Other social se...|[Other social ser...|                null|                null|                null|[[JB,Other social...|            JB|  IBRD|Active|                   N|[Participation an...|[[57,Participatio...|         59,57|        0|     1500000|http://www.worldb...|
# |[52b213b38594d8a2...|      2014|             October|2013-10-31T00:00:00Z| MINISTRY OF FINANCE|2019-04-30T00:00:00Z|Kingdom of Lesoth...|         LS|  Kingdom of Lesotho|           Lesotho|Project Informati...|                       B|       0|          0|P144933|  13100000|MINISTRY OF TRADE...|Investment Projec...|              IN|       15000000|[[Industry and tr...|[[YX,Industry and...|[Trade and integr...|[[5,Trade and int...|        5,4|      PE|            IBRD/IDA|              L|[The development ...|Second Private Se...|[[06-SEP-2013,PID...|                 IDA|              Active|              Africa|[[General industr...|[General industry...| [Other industry,40]|    [SME Finance,10]|                null|[[YZ,General indu...|      FH,YW,YZ|  IBRD|Active|                   N|[Export developme...|[[45,Export devel...|         41,45| 13100000|    13100000|http://www.worldb...|
# |[52b213b38594d8a2...|      2014|             October|2013-10-31T00:00:00Z|   REPUBLIC OF KENYA|                null|Republic of Kenya...|         KE|   Republic of Kenya|             Kenya|Integrated Safegu...|                       C|       0|          0|P146161|  10000000|                null|Investment Projec...|              IN|       66400000|[[Health and othe...|[[JX,Health and o...|[Social protectio...|[[6,Social protec...|        6,6|      PE|            IBRD/IDA|              L|                null|Additional Financ...|[[16-SEP-2013,ISD...|                 IDA|              Active|              Africa|[[Other social se...|[Other social ser...|                null|                null|                null|[[JB,Other social...|            JB|  IBRD|Active|                   Y|[Social safety ne...|[[54,Social safet...|            54| 10000000|    10000000|http://www.worldb...|
# |[52b213b38594d8a2...|      2014|             October|2013-10-29T00:00:00Z| GOVERNMENT OF INDIA|2019-06-30T00:00:00Z|Republic of India...|         IN|   Republic of India|             India|Project Appraisal...|                       A|       0|  500000000|P121185|         0|MINISTRY OF ROAD ...|Specific Investme...|              IN|     1146050000|[[Transportation,...|[[TX,Transportati...|[Public sector go...|[[2,Public sector...|        2,4|      PE|            IBRD/IDA|              L|[The development ...|National Highways...|[[02-OCT-2013,PAD...|                IBRD|              Active|          South Asia|[[Rural and Inter...|[Rural and Inter-...|                null|                null|                null|[[TI,Rural and In...|            TI|  IBRD|Active|                   N|[Administrative a...|[[25,Administrati...|         39,25|500000000|   500000000|http://www.worldb...|
# |[52b213b38594d8a2...|      2014|             October|2013-10-29T00:00:00Z|PEOPLE'S REPUBLIC...|                null|People's Republic...|         CN|People's Republic...|             China|Project Appraisal...|                       C|27280000|          0|P127033|         0|NATIONAL ENERGY A...|Investment Projec...|              IN|       27280000|[[Energy and mini...|[[LX,Energy and m...|[Environment and ...|[[11,Environment ...|       11,8|      GE|Global Environmen...|              L|[The development ...|China Renewable E...|[[18-SEP-2013,PAD...|               OTHER|              Active|East Asia and Pac...|[[Other Renewable...|[Other Renewable ...|                null|                null|                null|[[LR,Other Renewa...|            LR|  IBRD|Active|                   N|[Climate change,100]|[[81,Climate chan...|            81|        0|    27280000|http://www.worldb...|
# |[52b213b38594d8a2...|      2014|             October|2013-10-29T00:00:00Z|THE GOVERNMENT OF...|2018-12-31T00:00:00Z|Republic of India...|         IN|   Republic of India|             India|Project Appraisal...|                       B|       0|          0|P130164| 160000000|PUBLIC WORKS DEPA...|Specific Investme...|              IN|      227000000|[[Transportation,...|[[TX,Transportati...| [Rural development]|[[10,Rural develo...|       10,7|      PE|            IBRD/IDA|              L|[The development ...|Rajasthan Road Se...|[[01-OCT-2013,PAD...|                 IDA|              Active|          South Asia|[[Rural and Inter...|[Rural and Inter-...|                null|                null|                null|[[TI,Rural and In...|            TI|  IBRD|Active|                   N|[Other rural deve...|[[79,Other rural ...|            79|160000000|   160000000|http://www.worldb...|
# |[52b213b38594d8a2...|      2014|             October|2013-10-29T00:00:00Z|THE KINGDOM OF MO...|2014-12-31T00:00:00Z|Kingdom of Morocc...|         MA|  Kingdom of Morocco|           Morocco|Program Document,...|                    null|       0|  200000000|P130903|         0| MINISTRY OF FINANCE|Development Polic...|              AD|      200000000|[[Public Administ...|[[BX,Public Admin...|[Public sector go...|[[2,Public sector...|      2,2,2|      PE|            IBRD/IDA|              L|[The objective of...|MA Accountability...|[[30-SEP-2013,PGD...|                IBRD|              Active|Middle East and N...|[[General public ...|[General public a...|[Central governme...|[Public administr...|                null|[[BZ,General publ...|      BM,BC,BZ|  IBRD|Active|                   N|[Other accountabi...|[[29,Other accoun...|      27,30,29|200000000|   200000000|http://www.worldb...|
# |[52b213b38594d8a2...|      2014|             October|2013-10-25T00:00:00Z|GOVERNMENT OF SOU...|                null|Republic of South...|         SS|Republic of South...|       South Sudan|Project Paper,Pro...|                       B| 7530000|          0|P145339|         0|MINISTRY OF AGRIC...|Specific Investme...|              IN|        7530000|[[Agriculture, fi...|[[AX,Agriculture,...| [Rural development]|[[10,Rural develo...|       10,2|      RE|Recipient Execute...|              L|[The development ...|Southern Sudan Em...|[[01-OCT-2013,PJP...|               OTHER|              Active|              Africa|[[Crops], [Other ...|          [Crops,50]|[Other social ser...|[General agricult...|                null|[[AH,Crops], [JB,...|      AZ,JB,AH|  IBRD|Active|                   Y|[Global food cris...|[[91,Global food ...|            91|        0|     7530000|http://www.worldb...|
# |[52b213b38594d8a2...|      2014|             October|2013-10-25T00:00:00Z|                null|2017-12-31T00:00:00Z|Republic of India...|         IN|   Republic of India|             India|Project Appraisal...|                       B|       0|          0|P146653| 250000000|                null|Investment Projec...|              IN|      250000000|[[Transportation,...|[[TX,Transportati...|[Rural developmen...|[[10,Rural develo...|  10,6,6,11|      PE|            IBRD/IDA|              L|[The objective of...|Uttarakhand Disas...|[[11-OCT-2013,PAD...|                 IDA|              Active|          South Asia|[[Rural and Inter...|[Rural and Inter-...|[Flood protection...|[Housing construc...|[Other social ser...|[[TI,Rural and In...|   JB,YC,WD,TI|  IBRD|Active|                   N|[Rural services a...|[[78,Rural servic...|   81,87,52,78|250000000|   250000000|http://www.worldb...|
# |[52b213b38594d8a2...|      2014|             October|2013-10-24T00:00:00Z| GOVERNMENT OF GHANA|2019-06-30T00:00:00Z|Republic of Ghana...|         GH|   Republic of Ghana|             Ghana|Project Appraisal...|                       C|       0|          0|P144140|  97000000|MINISTRY OF COMMU...|Specific Investme...|              IN|       97000000|[[Information and...|[[CX,Information ...|                null|              [[4,]]|          4|      PE|            IBRD/IDA|              L|[The development ...| GH eTransform Ghana|[[26-SEP-2013,PAD...|                 IDA|              Active|              Africa|[[General informa...|[General informat...|                null|                null|                null|[[CZ,General info...|            CZ|  IBRD|Active|                   N|                [,0]|                null|          null| 97000000|    97000000|http://www.worldb...|
# |[52b213b38594d8a2...|      2014|             October|2013-10-22T00:00:00Z|GOVERNMENT OF TIM...|                null|Democratic Republ...|         TP|Democratic Republ...|       Timor-Leste|Integrated Safegu...|                       B|       0|   15000000|P130975|  25000000|MINISTRY OF INFRA...|Specific Investme...|              IN|       92000000|[[Transportation,...|[[TX,Transportati...|[Trade and integr...|[[5,Trade and int...|    5,11,10|      PE|            IBRD/IDA|              L|[The development ...|Timor Leste Road ...|[[11-SEP-2012,ISD...|                IBRD|              Active|East Asia and Pac...|[[Rural and Inter...|[Rural and Inter-...|[Public administr...|                null|                null|[[TI,Rural and In...|         BV,TI|  IBRD|Active|                   Y|[Regional integra...|[[47,Regional int...|      78,81,47| 40000000|    40000000|http://www.worldb...|
# |[52b213b38594d8a2...|      2014|             October|2013-10-22T00:00:00Z|GOVERNMENT OF JORDAN|                null|Hashemite Kingdom...|         JO|Hashemite Kingdom...|            Jordan|                null|                       C| 9500000|          0|P144832|         0|MINISTRY OF PLANN...|Technical Assista...|              IN|       10000000|[[Health and othe...|[[JX,Health and o...|[Social protectio...|[[6,Social protec...|      6,6,6|      RE|Recipient Execute...|              L|                null|NATIONAL UNIFIED ...|                null|               OTHER|              Active|Middle East and N...|[[Other social se...|[Other social ser...|                null|                null|                null|[[JB,Other social...|            JB|  IBRD|Active|                   N|[Social safety ne...|[[54,Social safet...|      53,56,54|        0|     9500000|http://www.worldb...|
# |[52b213b38594d8a2...|      2014|             October|2013-10-17T00:00:00Z| MINISTRY OF FINANCE|2019-04-30T00:00:00Z|          Samoa!$!WS|         WS|               Samoa|             Samoa|Environmental Ass...|                       B|       0|          0|P145545|  20000000|LAND TRANSPORT AU...|Investment Projec...|              IN|       20000000|[[Transportation,...|[[TX,Transportati...|[Rural developmen...|[[10,Rural develo...|    10,11,5|      PE|            IBRD/IDA|              L|[The development ...|Enhanced Road Acc...|[[21-AUG-2013,EA,...|                 IDA|              Active|East Asia and Pac...|[[Rural and Inter...|[Rural and Inter-...|                null|                null|                null|[[TI,Rural and In...|            TI|  IBRD|Active|                   N|[Rural services a...|[[78,Rural servic...|      49,81,78| 20000000|    20000000|http://www.worldb...|
# |[52b213b38594d8a2...|      2014|             October|2013-10-17T00:00:00Z| MINISTRY OF FINANCE|2015-12-31T00:00:00Z|          Samoa!$!WS|         WS|               Samoa|             Samoa|Project Appraisal...|                       B|       0|          0|P145938|   5000000|MINISTRY OF AGRIC...|Investment Projec...|              IN|        5000000|[[Agriculture, fi...|[[AX,Agriculture,...| [Rural development]|[[10,Rural develo...|       10,2|      PE|            IBRD/IDA|              L|[The development ...|Samoa Agriculture...|[[19-SEP-2013,PAD...|                 IDA|              Active|East Asia and Pac...|[[Crops], [Animal...|          [Crops,50]|[Animal productio...|[General agricult...|                null|[[AH,Crops], [AJ,...|      AZ,AJ,AH|  IBRD|Active|                   N|[Other rural deve...|[[79,Other rural ...|            79|  5000000|     5000000|http://www.worldb...|
# |[52b213b38594d8a2...|      2014|             October|2013-10-16T00:00:00Z|MINISTRY OF FINAN...|                null|Republic of Madag...|         MG|Republic of Madag...|        Madagascar|Integrated Safegu...|                       B|85400000|          0|P132616|         0|MINISTRY OF EDUCA...|Emergency Recover...|              IN|       85400000|   [[Education,100]]|    [[EX,Education]]| [Human development]|[[8,Human develop...|        8,7|      RE|Recipient Execute...|              L|                null|Emergency Support...|[[21-SEP-2013,ISD...|               OTHER|              Active|              Africa|[[Primary educati...|[Primary educatio...|                null|                null|                null|[[EP,Primary educ...|            EP|  IBRD|Active|                   N|[Education for al...|[[65,Education fo...|            65|        0|    85400000|http://www.worldb...|
# |[52b213b38594d8a2...|      2014|             October|2013-10-16T00:00:00Z|ROYAL GOVERNMENT ...|                null|Kingdom of Cambod...|         KH| Kingdom of Cambodia|          Cambodia|Project Informati...|                       B|13450000|          0|P146271|         0|  MINISTRY OF HEALTH|Investment Projec...|              IN|       13450000|[[Health and othe...|[[JX,Health and o...|[Human developmen...|[[8,Human develop...|  8,8,2,7,8|      RE|Recipient Execute...|              L|                null|Additional Financ...|[[14-OCT-2013,PID...|               OTHER|              Active|East Asia and Pac...|[[Health], [Centr...|         [Health,44]|[Central governme...|[Sub-national gov...|[Other social ser...|[[JA,Health], [BC...|BK,JB,BH,BC,JA|  IBRD|Active|                   Y|   [Child health,17]|[[63,Child health...|69,57,25,67,63|        0|    13450000|http://www.worldb...|
# |[52b213b38594d8a2...|      2014|             October|2013-10-10T00:00:00Z| MINISTRY OF FINANCE|                null|Kingdom of Morocc...|         MA|  Kingdom of Morocco|           Morocco|Project Informati...|                       C| 4350000|          0|P143979|         0| MINISTRY OF FINANCE|Specific Investme...|              IN|        4550000|[[Public Administ...|[[BX,Public Admin...|[Public sector go...|[[2,Public sector...|      2,2,2|      RE|Recipient Execute...|              L|                null|DTF:MA- Support N...|[[23-JAN-2013,PID...|               OTHER|              Active|Middle East and N...|[[General public ...|[General public a...|[Central governme...|[Sub-national gov...|                null|[[BZ,General publ...|      BH,BC,BZ|  IBRD|Active|                   N|[Public expenditu...|[[27,Public expen...|      25,26,27|        0|     4350000|http://www.worldb...|
# +--------------------+----------+--------------------+--------------------+--------------------+--------------------+--------------------+-----------+--------------------+------------------+--------------------+------------------------+--------+-----------+-------+----------+--------------------+--------------------+----------------+---------------+--------------------+--------------------+--------------------+--------------------+-----------+--------+--------------------+---------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------+------+------+--------------------+--------------------+--------------------+--------------+---------+------------+--------------------+
# only showing top 20 rows
#
# total 1536
# -rw-r--r-- 1 s389-7c57b6f1118293-591ae43264f0 users      0 Nov 28 10:43 _SUCCESS
# -rw-r--r-- 1 s389-7c57b6f1118293-591ae43264f0 users 522921 Nov 28 10:43 part-r-00000-90977dc4-baaf-4c06-bd95-1bde3f06e7c1.snappy.parquet
# total 1368
# -rw-r--r-- 1 s389-7c57b6f1118293-591ae43264f0   3888 Nov 23 10:33 README.md
# -rw-r--r-- 1 s389-7c57b6f1118293-591ae43264f0    244 Nov 23 10:53 StockPrices.csv
# drwxr-xr-x 2 s389-7c57b6f1118293-591ae43264f0   4096 Nov 28 10:43 blahblah.parquet/
# -rw-r--r-- 1 s389-7c57b6f1118293-591ae43264f0    977 Nov 10 10:14 pred_c.gz
# -rw-r--r-- 1 s389-7c57b6f1118293-591ae43264f0  11431 Nov 10 10:14 product.csv
# -rw-r--r-- 1 s389-7c57b6f1118293-591ae43264f0 446287 Nov 23 11:18 world_bank.json.gz
# UID        PID  PPID  C STIME TTY          TIME CMD
# root         1     0  0 Nov18 ?        00:00:13 /usr/lib/systemd/systemd --switc
# root         2     0  0 Nov18 ?        00:00:00 [kthreadd]
# root         3     2  0 Nov18 ?        00:00:00 [ksoftirqd/0]
# root         5     2  0 Nov18 ?        00:00:00 [kworker/0:0H]
# root         8     2  0 Nov18 ?        00:00:01 [migration/0]
# root         9     2  0 Nov18 ?        00:00:00 [rcu_bh]
# root        10     2  0 Nov18 ?        00:00:00 [rcuob/0]
# root        11     2  0 Nov18 ?        00:00:00 [rcuob/1]
# root        12     2  0 Nov18 ?        00:00:00 [rcuob/2]
# root        13     2  0 Nov18 ?        00:00:00 [rcuob/3]
# root        14     2  0 Nov18 ?        00:00:00 [rcuob/4]
# root        15     2  0 Nov18 ?        00:00:00 [rcuob/5]
# root        16     2  0 Nov18 ?        00:00:00 [rcuob/6]
# root        17     2  0 Nov18 ?        00:00:00 [rcuob/7]
# root        18     2  0 Nov18 ?        00:00:00 [rcuob/8]
# root        19     2  0 Nov18 ?        00:00:00 [rcuob/9]
# root        20     2  0 Nov18 ?        00:00:00 [rcuob/10]
# root        21     2  0 Nov18 ?        00:00:00 [rcuob/11]
# root        22     2  0 Nov18 ?        00:00:00 [rcuob/12]
# root        23     2  0 Nov18 ?        00:00:00 [rcuob/13]
# root        24     2  0 Nov18 ?        00:00:00 [rcuob/14]
# root        25     2  0 Nov18 ?        00:00:00 [rcuob/15]
# root        26     2  0 Nov18 ?        00:00:00 [rcuob/16]
# root        27     2  0 Nov18 ?        00:00:00 [rcuob/17]
# root        28     2  0 Nov18 ?        00:00:00 [rcuob/18]
# root        29     2  0 Nov18 ?        00:00:00 [rcuob/19]
# root        30     2  0 Nov18 ?        00:00:00 [rcuob/20]
# root        31     2  0 Nov18 ?        00:00:00 [rcuob/21]
# root        32     2  0 Nov18 ?        00:00:00 [rcuob/22]
# root        33     2  0 Nov18 ?        00:00:00 [rcuob/23]
# root        34     2  0 Nov18 ?        00:00:00 [rcuob/24]
# root        35     2  0 Nov18 ?        00:00:00 [rcuob/25]
# root        36     2  0 Nov18 ?        00:00:00 [rcuob/26]
# root        37     2  0 Nov18 ?        00:00:00 [rcuob/27]
# root        38     2  0 Nov18 ?        00:00:00 [rcuob/28]
# root        39     2  0 Nov18 ?        00:00:00 [rcuob/29]
# root        40     2  0 Nov18 ?        00:00:00 [rcuob/30]
# root        41     2  0 Nov18 ?        00:00:00 [rcuob/31]
# root        42     2  0 Nov18 ?        00:00:00 [rcuob/32]
# root        43     2  0 Nov18 ?        00:00:00 [rcuob/33]
# root        44     2  0 Nov18 ?        00:00:00 [rcuob/34]
# root        45     2  0 Nov18 ?        00:00:00 [rcuob/35]
# root        46     2  0 Nov18 ?        00:00:00 [rcuob/36]
# root        47     2  0 Nov18 ?        00:00:00 [rcuob/37]
# root        48     2  0 Nov18 ?        00:00:00 [rcuob/38]
# root        49     2  0 Nov18 ?        00:00:00 [rcuob/39]
# root        50     2  0 Nov18 ?        00:00:00 [rcuob/40]
# root        51     2  0 Nov18 ?        00:00:00 [rcuob/41]
# root        52     2  0 Nov18 ?        00:00:00 [rcuob/42]
# root        53     2  0 Nov18 ?        00:00:00 [rcuob/43]
# root        54     2  0 Nov18 ?        00:00:00 [rcuob/44]
# root        55     2  0 Nov18 ?        00:00:00 [rcuob/45]
# root        56     2  0 Nov18 ?        00:00:00 [rcuob/46]
# root        57     2  0 Nov18 ?        00:00:00 [rcuob/47]
# root        58     2  0 Nov18 ?        00:30:31 [rcu_sched]
# root        59     2  0 Nov18 ?        00:02:18 [rcuos/0]
# root        60     2  0 Nov18 ?        00:02:20 [rcuos/1]
# root        61     2  0 Nov18 ?        00:03:06 [rcuos/2]
# root        62     2  0 Nov18 ?        00:03:27 [rcuos/3]
# root        63     2  0 Nov18 ?        00:03:07 [rcuos/4]
# root        64     2  0 Nov18 ?        00:02:49 [rcuos/5]
# root        65     2  0 Nov18 ?        00:02:40 [rcuos/6]
# root        66     2  0 Nov18 ?        00:02:34 [rcuos/7]
# root        67     2  0 Nov18 ?        00:02:31 [rcuos/8]
# root        68     2  0 Nov18 ?        00:02:28 [rcuos/9]
# root        69     2  0 Nov18 ?        00:02:26 [rcuos/10]
# root        70     2  0 Nov18 ?        00:02:24 [rcuos/11]
# root        71     2  0 Nov18 ?        00:01:01 [rcuos/12]
# root        72     2  0 Nov18 ?        00:00:58 [rcuos/13]
# root        73     2  0 Nov18 ?        00:01:40 [rcuos/14]
# root        74     2  0 Nov18 ?        00:02:13 [rcuos/15]
# root        75     2  0 Nov18 ?        00:01:43 [rcuos/16]
# root        76     2  0 Nov18 ?        00:01:29 [rcuos/17]
# root        77     2  0 Nov18 ?        00:01:18 [rcuos/18]
# root        78     2  0 Nov18 ?        00:01:11 [rcuos/19]
# root        79     2  0 Nov18 ?        00:01:09 [rcuos/20]
# root        80     2  0 Nov18 ?        00:01:06 [rcuos/21]
# root        81     2  0 Nov18 ?        00:01:03 [rcuos/22]
# root        82     2  0 Nov18 ?        00:01:03 [rcuos/23]
# root        83     2  0 Nov18 ?        00:00:20 [rcuos/24]
# root        84     2  0 Nov18 ?        00:02:34 [rcuos/25]
# root        85     2  0 Nov18 ?        00:02:25 [rcuos/26]
# root        86     2  0 Nov18 ?        00:01:14 [rcuos/27]
# root        87     2  0 Nov18 ?        00:00:48 [rcuos/28]
# root        88     2  0 Nov18 ?        00:00:41 [rcuos/29]
# root        89     2  0 Nov18 ?        00:00:36 [rcuos/30]
# root        90     2  0 Nov18 ?        00:00:31 [rcuos/31]
# root        91     2  0 Nov18 ?        00:00:27 [rcuos/32]
# root        92     2  0 Nov18 ?        00:00:25 [rcuos/33]
# root        93     2  0 Nov18 ?        00:00:23 [rcuos/34]
# root        94     2  0 Nov18 ?        00:00:25 [rcuos/35]
# root        95     2  0 Nov18 ?        00:00:10 [rcuos/36]
# root        96     2  0 Nov18 ?        00:02:24 [rcuos/37]
# root        97     2  0 Nov18 ?        00:02:21 [rcuos/38]
# root        98     2  0 Nov18 ?        00:00:59 [rcuos/39]
# root        99     2  0 Nov18 ?        00:00:36 [rcuos/40]
# root       100     2  0 Nov18 ?        00:00:33 [rcuos/41]
# root       101     2  0 Nov18 ?        00:00:26 [rcuos/42]
# root       102     2  0 Nov18 ?        00:00:21 [rcuos/43]
# root       103     2  0 Nov18 ?        00:00:18 [rcuos/44]
# root       104     2  0 Nov18 ?        00:00:15 [rcuos/45]
# root       105     2  0 Nov18 ?        00:00:12 [rcuos/46]
# root       106     2  0 Nov18 ?        00:00:16 [rcuos/47]
# root       107     2  0 Nov18 ?        00:00:01 [watchdog/0]
# root       108     2  0 Nov18 ?        00:00:02 [watchdog/1]
# root       109     2  0 Nov18 ?        00:00:01 [migration/1]
# root       110     2  0 Nov18 ?        00:00:00 [ksoftirqd/1]
# root       113     2  0 Nov18 ?        00:00:01 [watchdog/2]
# root       114     2  0 Nov18 ?        00:00:02 [migration/2]
# root       115     2  0 Nov18 ?        00:00:00 [ksoftirqd/2]
# root       117     2  0 Nov18 ?        00:00:00 [kworker/2:0H]
# root       118     2  0 Nov18 ?        00:00:01 [watchdog/3]
# root       119     2  0 Nov18 ?        00:00:02 [migration/3]
# root       120     2  0 Nov18 ?        00:00:00 [ksoftirqd/3]
# root       122     2  0 Nov18 ?        00:00:00 [kworker/3:0H]
# root       123     2  0 Nov18 ?        00:00:01 [watchdog/4]
# root       124     2  0 Nov18 ?        00:00:02 [migration/4]
# root       125     2  0 Nov18 ?        00:00:00 [ksoftirqd/4]
# root       127     2  0 Nov18 ?        00:00:00 [kworker/4:0H]
# root       128     2  0 Nov18 ?        00:00:01 [watchdog/5]
# root       129     2  0 Nov18 ?        00:00:02 [migration/5]
# root       130     2  0 Nov18 ?        00:00:00 [ksoftirqd/5]
# root       132     2  0 Nov18 ?        00:00:00 [kworker/5:0H]
# root       133     2  0 Nov18 ?        00:00:01 [watchdog/6]
# root       134     2  0 Nov18 ?        00:00:02 [migration/6]
# root       135     2  0 Nov18 ?        00:00:00 [ksoftirqd/6]
# root       137     2  0 Nov18 ?        00:00:00 [kworker/6:0H]
# root       138     2  0 Nov18 ?        00:00:01 [watchdog/7]
# root       139     2  0 Nov18 ?        00:00:01 [migration/7]
# root       140     2  0 Nov18 ?        00:00:00 [ksoftirqd/7]
# root       142     2  0 Nov18 ?        00:00:00 [kworker/7:0H]
# root       143     2  0 Nov18 ?        00:00:01 [watchdog/8]
# root       144     2  0 Nov18 ?        00:00:02 [migration/8]
# root       145     2  0 Nov18 ?        00:00:00 [ksoftirqd/8]
# root       147     2  0 Nov18 ?        00:00:00 [kworker/8:0H]
# root       148     2  0 Nov18 ?        00:00:01 [watchdog/9]
# root       149     2  0 Nov18 ?        00:00:02 [migration/9]
# root       150     2  0 Nov18 ?        00:00:00 [ksoftirqd/9]
# root       152     2  0 Nov18 ?        00:00:00 [kworker/9:0H]
# root       153     2  0 Nov18 ?        00:00:01 [watchdog/10]
# root       154     2  0 Nov18 ?        00:00:01 [migration/10]
# root       155     2  0 Nov18 ?        00:00:00 [ksoftirqd/10]
# root       157     2  0 Nov18 ?        00:00:00 [kworker/10:0H]
# root       158     2  0 Nov18 ?        00:00:01 [watchdog/11]
# root       159     2  0 Nov18 ?        00:00:01 [migration/11]
# root       160     2  0 Nov18 ?        00:00:00 [ksoftirqd/11]
# root       162     2  0 Nov18 ?        00:00:00 [kworker/11:0H]
# root       163     2  0 Nov18 ?        00:00:02 [watchdog/12]
# root       164     2  0 Nov18 ?        00:00:01 [migration/12]
# root       165     2  0 Nov18 ?        00:00:00 [ksoftirqd/12]
# root       167     2  0 Nov18 ?        00:00:00 [kworker/12:0H]
# root       169     2  0 Nov18 ?        00:00:02 [watchdog/13]
# root       170     2  0 Nov18 ?        00:00:01 [migration/13]
# root       171     2  0 Nov18 ?        00:00:00 [ksoftirqd/13]
# root       174     2  0 Nov18 ?        00:00:02 [watchdog/14]
# root       175     2  0 Nov18 ?        00:00:02 [migration/14]
# root       176     2  0 Nov18 ?        00:00:00 [ksoftirqd/14]
# root       178     2  0 Nov18 ?        00:00:00 [kworker/14:0H]
# root       179     2  0 Nov18 ?        00:00:02 [watchdog/15]
# root       180     2  0 Nov18 ?        00:00:02 [migration/15]
# root       181     2  0 Nov18 ?        00:00:00 [ksoftirqd/15]
# root       183     2  0 Nov18 ?        00:00:00 [kworker/15:0H]
# root       184     2  0 Nov18 ?        00:00:02 [watchdog/16]
# root       185     2  0 Nov18 ?        00:00:02 [migration/16]
# root       186     2  0 Nov18 ?        00:00:00 [ksoftirqd/16]
# root       188     2  0 Nov18 ?        00:00:00 [kworker/16:0H]
# root       189     2  0 Nov18 ?        00:00:02 [watchdog/17]
# root       190     2  0 Nov18 ?        00:00:02 [migration/17]
# root       191     2  0 Nov18 ?        00:00:00 [ksoftirqd/17]
# root       193     2  0 Nov18 ?        00:00:00 [kworker/17:0H]
# root       194     2  0 Nov18 ?        00:00:02 [watchdog/18]
# root       195     2  0 Nov18 ?        00:00:01 [migration/18]
# root       196     2  0 Nov18 ?        00:00:00 [ksoftirqd/18]
# root       198     2  0 Nov18 ?        00:00:00 [kworker/18:0H]
# root       199     2  0 Nov18 ?        00:00:02 [watchdog/19]
# root       200     2  0 Nov18 ?        00:00:01 [migration/19]
# root       201     2  0 Nov18 ?        00:00:00 [ksoftirqd/19]
# root       203     2  0 Nov18 ?        00:00:00 [kworker/19:0H]
# root       204     2  0 Nov18 ?        00:00:02 [watchdog/20]
# root       205     2  0 Nov18 ?        00:00:01 [migration/20]
# root       206     2  0 Nov18 ?        00:00:00 [ksoftirqd/20]
# root       208     2  0 Nov18 ?        00:00:00 [kworker/20:0H]
# root       209     2  0 Nov18 ?        00:00:02 [watchdog/21]
# root       210     2  0 Nov18 ?        00:00:01 [migration/21]
# root       211     2  0 Nov18 ?        00:00:00 [ksoftirqd/21]
# root       213     2  0 Nov18 ?        00:00:00 [kworker/21:0H]
# root       214     2  0 Nov18 ?        00:00:02 [watchdog/22]
# root       215     2  0 Nov18 ?        00:00:01 [migration/22]
# root       216     2  0 Nov18 ?        00:00:00 [ksoftirqd/22]
# root       218     2  0 Nov18 ?        00:00:00 [kworker/22:0H]
# root       219     2  0 Nov18 ?        00:00:02 [watchdog/23]
# root       220     2  0 Nov18 ?        00:00:01 [migration/23]
# root       221     2  0 Nov18 ?        00:00:00 [ksoftirqd/23]
# root       223     2  0 Nov18 ?        00:00:00 [kworker/23:0H]
# root       224     2  0 Nov18 ?        00:00:01 [watchdog/24]
# root       225     2  0 Nov18 ?        00:00:01 [migration/24]
# root       226     2  0 Nov18 ?        00:00:00 [ksoftirqd/24]
# root       228     2  0 Nov18 ?        00:00:00 [kworker/24:0H]
# root       229     2  0 Nov18 ?        00:00:01 [watchdog/25]
# root       230     2  0 Nov18 ?        00:00:23 [migration/25]
# root       231     2  0 Nov18 ?        00:00:00 [ksoftirqd/25]
# root       233     2  0 Nov18 ?        00:00:00 [kworker/25:0H]
# root       234     2  0 Nov18 ?        00:00:01 [watchdog/26]
# root       235     2  0 Nov18 ?        00:00:11 [migration/26]
# root       236     2  0 Nov18 ?        00:00:00 [ksoftirqd/26]
# root       238     2  0 Nov18 ?        00:00:00 [kworker/26:0H]
# root       239     2  0 Nov18 ?        00:00:01 [watchdog/27]
# root       240     2  0 Nov18 ?        00:00:04 [migration/27]
# root       241     2  0 Nov18 ?        00:00:00 [ksoftirqd/27]
# root       243     2  0 Nov18 ?        00:00:00 [kworker/27:0H]
# root       244     2  0 Nov18 ?        00:00:01 [watchdog/28]
# root       245     2  0 Nov18 ?        00:00:03 [migration/28]
# root       246     2  0 Nov18 ?        00:00:00 [ksoftirqd/28]
# root       248     2  0 Nov18 ?        00:00:00 [kworker/28:0H]
# root       249     2  0 Nov18 ?        00:00:01 [watchdog/29]
# root       250     2  0 Nov18 ?        00:00:02 [migration/29]
# root       251     2  0 Nov18 ?        00:00:00 [ksoftirqd/29]
# root       253     2  0 Nov18 ?        00:00:00 [kworker/29:0H]
# root       254     2  0 Nov18 ?        00:00:01 [watchdog/30]
# root       255     2  0 Nov18 ?        00:00:02 [migration/30]
# root       256     2  0 Nov18 ?        00:00:00 [ksoftirqd/30]
# root       258     2  0 Nov18 ?        00:00:00 [kworker/30:0H]
# root       259     2  0 Nov18 ?        00:00:01 [watchdog/31]
# root       260     2  0 Nov18 ?        00:00:02 [migration/31]
# root       261     2  0 Nov18 ?        00:00:00 [ksoftirqd/31]
# root       263     2  0 Nov18 ?        00:00:00 [kworker/31:0H]
# root       264     2  0 Nov18 ?        00:00:01 [watchdog/32]
# root       265     2  0 Nov18 ?        00:00:01 [migration/32]
# root       266     2  0 Nov18 ?        00:00:00 [ksoftirqd/32]
# root       268     2  0 Nov18 ?        00:00:00 [kworker/32:0H]
# root       269     2  0 Nov18 ?        00:00:01 [watchdog/33]
# root       270     2  0 Nov18 ?        00:00:01 [migration/33]
# root       271     2  0 Nov18 ?        00:00:00 [ksoftirqd/33]
# root       273     2  0 Nov18 ?        00:00:00 [kworker/33:0H]
# root       274     2  0 Nov18 ?        00:00:01 [watchdog/34]
# root       275     2  0 Nov18 ?        00:00:01 [migration/34]
# root       276     2  0 Nov18 ?        00:00:00 [ksoftirqd/34]
# root       278     2  0 Nov18 ?        00:00:00 [kworker/34:0H]
# root       279     2  0 Nov18 ?        00:00:01 [watchdog/35]
# root       280     2  0 Nov18 ?        00:00:01 [migration/35]
# root       281     2  0 Nov18 ?        00:00:00 [ksoftirqd/35]
# root       283     2  0 Nov18 ?        00:00:00 [kworker/35:0H]
# root       284     2  0 Nov18 ?        00:00:02 [watchdog/36]
# root       285     2  0 Nov18 ?        00:00:01 [migration/36]
# root       286     2  0 Nov18 ?        00:00:00 [ksoftirqd/36]
# root       288     2  0 Nov18 ?        00:00:00 [kworker/36:0H]
# root       289     2  0 Nov18 ?        00:00:02 [watchdog/37]
# root       290     2  0 Nov18 ?        00:00:26 [migration/37]
# root       291     2  0 Nov18 ?        00:00:00 [ksoftirqd/37]
# root       293     2  0 Nov18 ?        00:00:00 [kworker/37:0H]
# root       294     2  0 Nov18 ?        00:00:02 [watchdog/38]
# root       295     2  0 Nov18 ?        00:00:11 [migration/38]
# root       296     2  0 Nov18 ?        00:00:00 [ksoftirqd/38]
# root       298     2  0 Nov18 ?        00:00:00 [kworker/38:0H]
# root       299     2  0 Nov18 ?        00:00:02 [watchdog/39]
# root       300     2  0 Nov18 ?        00:00:05 [migration/39]
# root       301     2  0 Nov18 ?        00:00:00 [ksoftirqd/39]
# root       303     2  0 Nov18 ?        00:00:00 [kworker/39:0H]
# root       304     2  0 Nov18 ?        00:00:02 [watchdog/40]
# root       305     2  0 Nov18 ?        00:00:05 [migration/40]
# root       306     2  0 Nov18 ?        00:00:00 [ksoftirqd/40]
# root       308     2  0 Nov18 ?        00:00:00 [kworker/40:0H]
# root       309     2  0 Nov18 ?        00:00:02 [watchdog/41]
# root       310     2  0 Nov18 ?        00:00:03 [migration/41]
# root       311     2  0 Nov18 ?        00:00:00 [ksoftirqd/41]
# root       313     2  0 Nov18 ?        00:00:00 [kworker/41:0H]
# root       314     2  0 Nov18 ?        00:00:02 [watchdog/42]
# root       315     2  0 Nov18 ?        00:00:02 [migration/42]
# root       316     2  0 Nov18 ?        00:00:00 [ksoftirqd/42]
# root       317     2  0 Nov18 ?        00:00:05 [kworker/42:0]
# root       318     2  0 Nov18 ?        00:00:00 [kworker/42:0H]
# root       319     2  0 Nov18 ?        00:00:02 [watchdog/43]
# root       320     2  0 Nov18 ?        00:00:02 [migration/43]
# root       321     2  0 Nov18 ?        00:00:00 [ksoftirqd/43]
# root       323     2  0 Nov18 ?        00:00:00 [kworker/43:0H]
# root       324     2  0 Nov18 ?        00:00:01 [watchdog/44]
# root       325     2  0 Nov18 ?        00:00:02 [migration/44]
# root       326     2  0 Nov18 ?        00:00:00 [ksoftirqd/44]
# root       328     2  0 Nov18 ?        00:00:00 [kworker/44:0H]
# root       329     2  0 Nov18 ?        00:00:02 [watchdog/45]
# root       330     2  0 Nov18 ?        00:00:01 [migration/45]
# root       331     2  0 Nov18 ?        00:00:00 [ksoftirqd/45]
# root       332     2  0 Nov18 ?        00:00:03 [kworker/45:0]
# root       333     2  0 Nov18 ?        00:00:00 [kworker/45:0H]
# root       334     2  0 Nov18 ?        00:00:02 [watchdog/46]
# root       335     2  0 Nov18 ?        00:00:01 [migration/46]
# root       336     2  0 Nov18 ?        00:00:00 [ksoftirqd/46]
# root       338     2  0 Nov18 ?        00:00:00 [kworker/46:0H]
# root       339     2  0 Nov18 ?        00:00:02 [watchdog/47]
# root       340     2  0 Nov18 ?        00:00:01 [migration/47]
# root       341     2  0 Nov18 ?        00:00:00 [ksoftirqd/47]
# root       343     2  0 Nov18 ?        00:00:00 [kworker/47:0H]
# root       344     2  0 Nov18 ?        00:00:00 [khelper]
# root       345     2  0 Nov18 ?        00:00:00 [kdevtmpfs]
# root       346     2  0 Nov18 ?        00:00:00 [netns]
# root       347     2  0 Nov18 ?        00:00:00 [perf]
# root       348     2  0 Nov18 ?        00:00:00 [writeback]
# root       349     2  0 Nov18 ?        00:00:00 [kintegrityd]
# root       350     2  0 Nov18 ?        00:00:00 [bioset]
# root       351     2  0 Nov18 ?        00:00:00 [kblockd]
# root       353     2  0 Nov18 ?        00:00:00 [md]
# root       357     2  0 Nov18 ?        00:00:08 [khungtaskd]
# root       358     2  0 Nov18 ?        00:00:00 [kswapd0]
# root       359     2  0 Nov18 ?        00:00:00 [kswapd1]
# root       360     2  0 Nov18 ?        00:00:00 [ksmd]
# root       361     2  0 Nov18 ?        00:00:06 [khugepaged]
# root       362     2  0 Nov18 ?        00:00:00 [fsnotify_mark]
# root       363     2  0 Nov18 ?        00:00:00 [crypto]
# root       371     2  0 Nov18 ?        00:00:00 [kthrotld]
# root       373     2  0 Nov18 ?        00:00:00 [kmpath_rdacd]
# root       411     2  0 Nov18 ?        00:00:04 [kworker/36:1]
# root       423     2  0 Nov18 ?        00:00:00 [kpsmoused]
# root       425     2  0 Nov18 ?        00:00:00 [ipv6_addrconf]
# root       445     2  0 Nov18 ?        00:00:00 [deferwq]
# root       487     2  0 Nov18 ?        00:00:01 [kauditd]
# root       627     2  0 Nov18 ?        00:00:00 [scsi_eh_0]
# root       628     2  0 Nov18 ?        00:00:00 [scsi_tmf_0]
# root       629     2  0 Nov18 ?        00:00:00 [ata_sff]
# root       630     2  0 Nov18 ?        00:00:00 [events_power_ef]
# root       641     2  0 Nov18 ?        00:00:00 [scsi_eh_1]
# root       642     2  0 Nov18 ?        00:00:00 [scsi_tmf_1]
# root       644     2  0 Nov18 ?        00:00:00 [scsi_eh_2]
# root       645     2  0 Nov18 ?        00:00:00 [scsi_tmf_2]
# root       646     2  0 Nov18 ?        00:00:00 [scsi_eh_3]
# root       647     2  0 Nov18 ?        00:00:00 [scsi_tmf_3]
# root       648     2  0 Nov18 ?        00:00:00 [scsi_eh_4]
# root       649     2  0 Nov18 ?        00:00:00 [scsi_tmf_4]
# s4ea-21+   655 46202  0 Nov21 ?        00:01:28 /usr/local/src/bluemix_jupyter_b
# root       663     2  0 Nov18 ?        00:00:00 [scsi_eh_5]
# root       664     2  0 Nov18 ?        00:00:00 [scsi_tmf_5]
# root       665     2  0 Nov18 ?        00:00:00 [scsi_eh_6]
# root       666     2  0 Nov18 ?        00:00:00 [scsi_tmf_6]
# root       667     2  0 Nov18 ?        00:00:00 [scsi_eh_7]
# root       668     2  0 Nov18 ?        00:00:00 [scsi_tmf_7]
# root       669     2  0 Nov18 ?        00:00:00 [scsi_eh_8]
# root       670     2  0 Nov18 ?        00:00:00 [scsi_tmf_8]
# root       671     2  0 Nov18 ?        00:00:00 [scsi_eh_9]
# root       672     2  0 Nov18 ?        00:00:00 [scsi_tmf_9]
# root       673     2  0 Nov18 ?        00:00:00 [scsi_eh_10]
# root       674     2  0 Nov18 ?        00:00:00 [scsi_tmf_10]
# root       795     2  0 Nov18 ?        00:00:00 [xfsalloc]
# root       796     2  0 Nov18 ?        00:00:00 [xfs_mru_cache]
# root       797     2  0 Nov18 ?        00:00:00 [xfs-buf/sda3]
# root       798     2  0 Nov18 ?        00:00:00 [xfs-data/sda3]
# root       799     2  0 Nov18 ?        00:00:00 [xfs-conv/sda3]
# root       800     2  0 Nov18 ?        00:00:00 [xfs-cil/sda3]
# root       801     2  0 Nov18 ?        00:00:00 [xfs-reclaim/sda]
# root       802     2  0 Nov18 ?        00:00:00 [xfs-log/sda3]
# root       803     2  0 Nov18 ?        00:00:00 [xfs-eofblocks/s]
# root       804     2  0 Nov18 ?        00:02:55 [xfsaild/sda3]
# root       873     1  0 Nov18 ?        00:00:07 /usr/lib/systemd/systemd-journal
# root       907     1  0 Nov18 ?        00:00:00 /usr/lib/systemd/systemd-udevd
# root       917     2  0 Nov18 ?        00:00:00 [kworker/18:1H]
# s4ea-21+  1043   655  0 Nov21 ?        00:40:22 /usr/local/src/spark160master/ib
# root      1065     2  0 Nov18 ?        00:01:05 [kipmi0]
# root      1066     2  0 Nov18 ?        00:00:00 [edac-poller]
# root      1160     2  0 Nov18 ?        00:00:00 [jbd2/sdd1-8]
# root      1161     2  0 Nov18 ?        00:00:00 [jbd2/sdf1-8]
# root      1162     2  0 Nov18 ?        00:00:00 [jbd2/sdh1-8]
# root      1163     2  0 Nov18 ?        00:00:00 [ext4-rsv-conver]
# root      1164     2  0 Nov18 ?        00:00:00 [ext4-unrsv-conv]
# root      1165     2  0 Nov18 ?        00:00:00 [ext4-rsv-conver]
# root      1166     2  0 Nov18 ?        00:00:00 [ext4-unrsv-conv]
# root      1167     2  0 Nov18 ?        00:00:00 [jbd2/sdg1-8]
# root      1168     2  0 Nov18 ?        00:00:00 [jbd2/sdb1-8]
# root      1169     2  0 Nov18 ?        00:00:00 [ext4-rsv-conver]
# root      1170     2  0 Nov18 ?        00:00:00 [jbd2/sdc1-8]
# root      1171     2  0 Nov18 ?        00:00:00 [ext4-unrsv-conv]
# root      1172     2  0 Nov18 ?        00:00:00 [jbd2/sdj1-8]
# root      1173     2  0 Nov18 ?        00:00:00 [jbd2/sde1-8]
# root      1174     2  0 Nov18 ?        00:00:00 [jbd2/sdi1-8]
# root      1175     2  0 Nov18 ?        00:00:00 [ext4-rsv-conver]
# root      1176     2  0 Nov18 ?        00:00:00 [ext4-unrsv-conv]
# root      1177     2  0 Nov18 ?        00:00:00 [ext4-rsv-conver]
# root      1178     2  0 Nov18 ?        00:00:00 [ext4-unrsv-conv]
# root      1179     2  0 Nov18 ?        00:00:00 [ext4-rsv-conver]
# root      1180     2  0 Nov18 ?        00:00:00 [ext4-rsv-conver]
# root      1181     2  0 Nov18 ?        00:00:00 [ext4-unrsv-conv]
# root      1182     2  0 Nov18 ?        00:00:00 [ext4-unrsv-conv]
# root      1183     2  0 Nov18 ?        00:00:00 [ext4-rsv-conver]
# root      1184     2  0 Nov18 ?        00:00:00 [ext4-unrsv-conv]
# root      1185     2  0 Nov18 ?        00:00:00 [ext4-rsv-conver]
# root      1186     2  0 Nov18 ?        00:00:00 [ext4-unrsv-conv]
# root      1207     2  0 Nov18 ?        00:00:00 [xfs-buf/sda1]
# root      1208     2  0 Nov18 ?        00:00:00 [xfs-data/sda1]
# root      1209     2  0 Nov18 ?        00:00:00 [xfs-conv/sda1]
# root      1210     2  0 Nov18 ?        00:00:00 [xfs-cil/sda1]
# root      1211     2  0 Nov18 ?        00:00:00 [xfs-reclaim/sda]
# root      1212     2  0 Nov18 ?        00:00:00 [xfs-log/sda1]
# root      1213     2  0 Nov18 ?        00:00:00 [xfs-eofblocks/s]
# root      1214     2  0 Nov18 ?        00:00:00 [xfsaild/sda1]
# root      1215     2  0 Nov18 ?        00:00:00 [kvm-irqfd-clean]
# root      1226     1  0 Nov18 ?        00:00:04 /sbin/auditd -n
# root      1249     1  0 Nov18 ?        00:04:48 /usr/sbin/irqbalance --foregroun
# root      1250     1  0 Nov18 ?        00:00:02 /usr/sbin/NetworkManager --no-da
# dbus      1255     1  0 Nov18 ?        00:00:00 /bin/dbus-daemon --system --addr
# root      1261     1  0 Nov18 ?        00:05:53 java -Dfile.encoding=UTF-8 -jar
# root      1263     1  0 Nov18 ?        00:00:20 /usr/sbin/sssd -D -f
# root      1264  1263  0 Nov18 ?        00:00:25 /usr/libexec/sssd/sssd_be --doma
# root      1265  1263  0 Nov18 ?        00:00:11 /usr/libexec/sssd/sssd_be --doma
# root      1286  1263  0 Nov18 ?        00:00:21 /usr/libexec/sssd/sssd_nss --uid
# root      1287  1263  0 Nov18 ?        00:00:08 /usr/libexec/sssd/sssd_pam --uid
# root      1288     2  0 Nov18 ?        00:00:00 [kworker/14:1H]
# avahi     1291     1  0 Nov18 ?        00:00:00 avahi-daemon: running [yp-spark-
# root      1295     1  0 Nov18 ?        00:00:01 /usr/lib/systemd/systemd-logind
# avahi     1300  1291  0 Nov18 ?        00:00:00 avahi-daemon: chroot helper
# root      1302     1  0 Nov18 ?        00:00:00 /usr/sbin/wpa_supplicant -u -f /
# polkitd   1303     1  0 Nov18 ?        00:00:00 /usr/lib/polkit-1/polkitd --no-d
# root      1308     2  0 Nov18 ?        00:00:00 [kworker/17:1H]
# ntp       1314     1  0 Nov18 ?        00:00:03 /usr/sbin/ntpd -u ntp:ntp -g
# ...
# sb79-94+ 33941 15276  0 Nov20 ?        00:00:00 /disk1/ego/3.4/linux-x86_64/etc/
# sb79-94+ 33942 33941  0 Nov20 ?        00:00:00 bash /usr/local/src/bluemix_jupy
# sb79-94+ 33943 33941  0 Nov20 ?        00:00:00 /disk1/ego/3.4/linux-x86_64/etc/
# sb79-94+ 33944 33943  0 Nov20 ?        00:00:04 /bin/bash /usr/local/src/bluemix
# sc35-f8+ 34016 22254  0 Nov20 ?        00:02:23 /usr/local/src/bluemix_jupyter_b
# root     34115     2  0 10:04 ?        00:00:00 [kworker/4:0]
# sb79-94+ 34124 33942  0 Nov20 ?        00:01:05 python /usr/local/src/bluemix_ju
# s389-7c+ 34146 45975  0 Nov23 ?        00:00:55 /usr/local/src/bluemix_jupyter_b
# sb79-94+ 34218 34124  0 Nov20 ?        00:00:00 /usr/local/src/bluemix_jupyter_b
# sb79-94+ 34297     1  0 Nov20 ?        00:41:03 /usr/local/src/spark160master/ib
# sc35-f8+ 34311 34016  0 Nov20 ?        00:38:32 /usr/local/src/spark160master/ib
# s389-7c+ 34630 34146  0 Nov23 ?        00:11:50 /usr/local/src/spark20master/ibm
# sc61-a8+ 34867 15276  0 Nov21 ?        00:00:00 /disk1/ego/3.4/linux-x86_64/etc/
# sc61-a8+ 34874 34867  0 Nov21 ?        00:00:00 bash /usr/local/src/bluemix_jupy
# sc61-a8+ 34875 34867  0 Nov21 ?        00:00:00 /disk1/ego/3.4/linux-x86_64/etc/
# sc61-a8+ 34876 34875  0 Nov21 ?        00:00:03 /bin/bash /usr/local/src/bluemix
# sc35-f8+ 34933 22254  0 Nov20 ?        00:05:40 /usr/local/src/bluemix_jupyter_b
# sc35-f8+ 35167 34933  0 Nov20 ?        00:37:17 /usr/local/src/spark160master/ib
# sc61-a8+ 35210 34874  0 Nov21 ?        00:03:52 python /usr/local/src/bluemix_ju
# root     35222     2  0 10:20 ?        00:00:00 [kworker/3:0]
# s300-bd+ 35236 12153  0 10:38 ?        00:00:00 sleep 300
# s179-d7+ 35266 38227  0 10:38 ?        00:00:00 sleep 300
# root     35402     2  0 Nov25 ?        00:00:01 [kworker/28:2]
# sc61-a8+ 35415 35210  0 Nov21 ?        00:01:13 /usr/local/src/bluemix_jupyter_b
# root     35500     2  0 07:31 ?        00:00:00 [kworker/22:0]
# s89f-f4+ 35561 40542  0 Nov24 ?        00:01:01 /usr/local/src/bluemix_jupyter_b
# sa4a-e7+ 35780 15276  0 10:38 ?        00:00:00 /disk1/ego/3.4/linux-x86_64/etc/
# sa4a-e7+ 35797 35780  0 10:38 ?        00:00:00 bash /usr/local/src/bluemix_jupy
# sa4a-e7+ 35798 35780  0 10:38 ?        00:00:00 /disk1/ego/3.4/linux-x86_64/etc/
# sa4a-e7+ 35799 35798  0 10:38 ?        00:00:00 /bin/bash /usr/local/src/bluemix
# sc61-a8+ 35813 35415  0 Nov21 ?        00:45:17 /usr/local/src/spark160master/ib
# s89f-f4+ 36229 35561  0 Nov24 ?        00:17:57 /usr/local/src/spark160master/ib
# root     36306     2  0 Nov26 ?        00:00:00 [kworker/1:0H]
# sd79-59+ 36498 15276  0 Nov24 ?        00:00:00 /disk1/ego/3.4/linux-x86_64/etc/
# sd79-59+ 36499 36498  0 Nov24 ?        00:00:00 bash /usr/local/src/bluemix_jupy
# sd79-59+ 36500 36498  0 Nov24 ?        00:00:00 /disk1/ego/3.4/linux-x86_64/etc/
# sd79-59+ 36501 36500  0 Nov24 ?        00:00:02 /bin/bash /usr/local/src/bluemix
# s300-bd+ 36572 12342  0 Nov25 ?        00:00:52 /usr/local/src/bluemix_jupyter_b
# root     36677     2  0 09:52 ?        00:00:00 [kworker/14:2]
# sa4a-e7+ 36691 35797  0 10:38 ?        00:00:00 python /usr/local/src/bluemix_ju
# sa4a-e7+ 36778 35799  0 10:38 ?        00:00:00 sleep 300
# sd79-59+ 36813 36499  0 Nov24 ?        00:00:38 python /usr/local/src/bluemix_ju
# s389-7c+ 36901 45768  0 10:38 ?        00:00:00 sleep 300
# s300-bd+ 36925 36572  0 Nov25 ?        00:17:15 /usr/local/src/spark160master/ib
# saf3-98+ 36927 23271  0 10:38 ?        00:00:00 sleep 300
# sb79-94+ 36935 33944  0 10:38 ?        00:00:00 sleep 300
# idcuser  37028 18623  0 10:38 ?        00:00:00 /bin/bash /opt/cdsmon/src/gpfs/g
# root     37029 37028  0 10:38 ?        00:00:00 sudo /usr/lpp/mmfs/bin/mmlsfs al
# idcuser  37030 37028  0 10:38 ?        00:00:00 grep File system attributes for
# idcuser  37031 37028  0 10:38 ?        00:00:00 sed s/.*for \(.*\):.*/\1/
# root     37032 37029  0 10:38 ?        00:00:00 /usr/lpp/mmfs/bin/mmksh /usr/lpp
# root     37164 37032  0 10:38 ?        00:00:00 /usr/lpp/mmfs/bin/mmksh /usr/lpp
# root     37187 37164  0 10:38 ?        00:00:00 /usr/lpp/mmfs/bin/.links/mmlsfs
# root     37504     2  0 Nov18 ?        00:00:00 [kworker/40:1H]
# s4ea-21+ 37582 45998  0 10:39 ?        00:00:00 sleep 300
# root     37639     2  0 Nov18 ?        00:00:00 [kworker/41:1H]
# root     37646     2  0 Nov18 ?        00:00:00 [kworker/47:1H]
# root     37656     2  0 Nov18 ?        00:00:00 [kworker/34:1H]
# sf65-23+ 37661 31330  0 10:39 ?        00:00:00 sleep 300
# root     37711     2  0 Nov18 ?        00:00:00 [kworker/46:1H]
# root     37763     2  0 Nov18 ?        00:00:00 [kworker/30:1H]
# s1ae-8d+ 37770  9955  0 10:39 ?        00:00:00 sleep 300
# s51e-6a+ 37918 16690  0 10:39 ?        00:00:00 sleep 300
# s810-7d+ 38016 31347  0 10:39 ?        00:00:00 sleep 300
# root     38087     2  0 Nov27 ?        00:00:00 [kworker/41:0]
# root     38090     2  0 10:22 ?        00:00:00 [kworker/18:0]
# s179-d7+ 38223 15276  0 Nov21 ?        00:00:00 /disk1/ego/3.4/linux-x86_64/etc/
# s179-d7+ 38225 38223  0 Nov21 ?        00:00:00 bash /usr/local/src/bluemix_jupy
# s179-d7+ 38226 38223  0 Nov21 ?        00:00:00 /disk1/ego/3.4/linux-x86_64/etc/
# s179-d7+ 38227 38226  0 Nov21 ?        00:00:03 /bin/bash /usr/local/src/bluemix
# s2de-8c+ 38268  9220  0 10:39 ?        00:00:00 sleep 300
# sc61-a8+ 38360 34876  0 10:39 ?        00:00:00 sleep 300
# s179-d7+ 38424 38225  0 Nov21 ?        00:02:45 python /usr/local/src/bluemix_ju
# s179-d7+ 38504 38424  0 Nov21 ?        00:01:46 /usr/local/src/bluemix_jupyter_b
# root     38623     2  0 Nov18 ?        00:00:00 [kworker/33:1H]
# root     38628     2  0 Nov25 ?        00:00:00 [kworker/40:2]
# root     38629     2  0 Nov25 ?        00:00:03 [kworker/40:3]
# s179-d7+ 38742 38504  0 Nov21 ?        00:34:46 /usr/local/src/spark160master/ib
# root     38747     2  0 Nov18 ?        00:00:00 [kworker/24:1H]
# sc61-a8+ 38821 35210  0 Nov27 ?        00:01:17 /usr/local/src/bluemix_jupyter_b
# root     39020     2  0 Nov18 ?        00:00:00 [kworker/32:1H]
# root     39062     2  0 Nov18 ?        00:00:00 [kworker/11:1H]
# root     39189     2  0 09:18 ?        00:00:00 [kworker/11:1]
# sc61-a8+ 39211 38821  0 Nov27 ?        00:05:05 /usr/local/src/spark160master/ib
# s2d2-91+ 39588 45654  0 10:07 ?        00:00:15 /usr/local/src/bluemix_jupyter_b
# s2d2-91+ 39903 39588  2 10:07 ?        00:00:57 /usr/local/src/spark160master/ib
# s89f-f4+ 40330 15276  0 Nov24 ?        00:00:00 /disk1/ego/3.4/linux-x86_64/etc/
# s89f-f4+ 40349 40330  0 Nov24 ?        00:00:00 bash /usr/local/src/bluemix_jupy
# s89f-f4+ 40350 40330  0 Nov24 ?        00:00:00 /disk1/ego/3.4/linux-x86_64/etc/
# s89f-f4+ 40351 40350  0 Nov24 ?        00:00:02 /bin/bash /usr/local/src/bluemix
# s89f-f4+ 40373 40351  0 10:39 ?        00:00:00 sleep 300
# s978-fd+ 40374 16709  0 10:39 ?        00:00:00 sleep 300
# root     40499     2  0 Nov18 ?        00:00:00 [kworker/45:1H]
# s89f-f4+ 40542 40349  0 Nov24 ?        00:01:30 python /usr/local/src/bluemix_ju
# sc61-a8+ 40581 35210  0 Nov26 ?        00:01:37 /usr/local/src/bluemix_jupyter_b
# root     40683     2  0 Nov24 ?        00:00:03 [kworker/43:1]
# root     40701     2  0 09:00 ?        00:00:00 [kworker/1:0]
# s291-18+ 40805 24889  0 10:39 ?        00:00:00 sleep 300
# sc61-a8+ 40869 40581  0 Nov26 ?        00:12:21 /usr/local/src/spark160master/ib
# sa31-8f+ 40880 14576  0 10:39 ?        00:00:00 sleep 300
# root     40943     2  0 10:39 ?        00:00:00 [kworker/18:1]
# root     40958     2  0 10:07 ?        00:00:00 [kworker/2:3]
# root     41028     2  0 09:53 ?        00:00:00 [kworker/2:1]
# se42-5d+ 41495 15276  0 04:25 ?        00:00:00 /disk1/ego/3.4/linux-x86_64/etc/
# se42-5d+ 41496 41495  0 04:25 ?        00:00:03 /bin/bash /usr/local/src/bluemix
# se42-5d+ 41497 41495  0 04:25 ?        00:00:00 /disk1/ego/3.4/linux-x86_64/etc/
# se42-5d+ 41498 41497  0 04:25 ?        00:00:00 /bin/bash /usr/local/src/bluemix
# se42-5d+ 41662 41496  0 04:25 ?        00:00:13 /usr/local/src/bluemix_ipythonsp
# sd79-59+ 41777 36501  0 10:40 ?        00:00:00 sleep 300
# root     41864     2  0 10:40 ?        00:00:00 [kworker/4:1]
# root     41865     2  0 10:40 ?        00:00:00 [kworker/5:0]
# root     41866     2  0 10:40 ?        00:00:00 [kworker/6:0]
# root     41867     2  0 10:40 ?        00:00:00 [kworker/8:1]
# root     41868     2  0 10:40 ?        00:00:00 [kworker/9:1]
# root     41901     2  0 Nov24 ?        00:00:00 [kworker/47:1]
# root     41915     2  0 05:25 ?        00:00:00 [kworker/29:0]
# root     42028     2  0 10:24 ?        00:00:00 [kworker/u96:1]
# se42-5d+ 42053 41662  0 04:25 ?        00:00:04 /usr/local/src/bluemix_ipythonsp
# se42-5d+ 42130 42053  0 04:26 ?        00:01:42 /usr/local/src/spark160master/ib
# root     42132     2  0 06:58 ?        00:00:03 [kworker/0:0]
# s99a-44+ 42277 18541  0 10:40 ?        00:00:00 sleep 300
# idcuser  42349 18622  0 10:40 ?        00:00:00 sleep 600
# s8b6-8b+ 42390 27798  0 10:40 ?        00:00:00 sleep 300
# root     42469     2  0 09:19 ?        00:00:00 [kworker/0:2]
# s1a9-ed+ 42723 10395  0 Nov23 ?        00:01:49 /usr/local/src/bluemix_jupyter_b
# root     43090     2  0 02:48 ?        00:00:00 [kworker/34:2]
# s2d2-91+ 43108 45375  0 10:40 ?        00:00:00 sleep 300
# s1a9-ed+ 43132 42723  0 Nov23 ?        00:12:11 /usr/local/src/spark20master/ibm
# root     43158     2  0 10:40 ?        00:00:00 [kworker/7:2]
# root     43189 15276  0 Nov18 ?        00:00:00 /disk1/ego/3.4/linux-x86_64/etc/
# root     43190 43189  0 Nov18 ?        01:13:28 /usr/local/src/spark160master/ib
# sbb6-28+ 43253 15276  0 Nov23 ?        00:00:00 /disk1/ego/3.4/linux-x86_64/etc/
# sbb6-28+ 43254 43253  0 Nov23 ?        00:00:00 bash /usr/local/src/bluemix_jupy
# sbb6-28+ 43255 43253  0 Nov23 ?        00:00:00 /disk1/ego/3.4/linux-x86_64/etc/
# sbb6-28+ 43256 43255  0 Nov23 ?        00:00:02 /bin/bash /usr/local/src/bluemix
# se42-5d+ 43470 41498  0 10:40 ?        00:00:00 sleep 300
# sb80-ae+ 43516 23304  0 10:40 ?        00:00:00 sleep 300
# sbb6-28+ 43628 43254  0 Nov23 ?        00:00:40 python /usr/local/src/bluemix_ju
# s68b-82+ 43649 15276  0 Nov21 ?        00:00:00 /disk1/ego/3.4/linux-x86_64/etc/
# s68b-82+ 43690 43649  0 Nov21 ?        00:00:00 bash /usr/local/src/bluemix_jupy
# s68b-82+ 43691 43649  0 Nov21 ?        00:00:00 /disk1/ego/3.4/linux-x86_64/etc/
# s68b-82+ 43692 43691  0 Nov21 ?        00:00:03 /bin/bash /usr/local/src/bluemix
# s68b-82+ 43865 43690  0 Nov21 ?        00:02:44 python /usr/local/src/bluemix_ju
# s3cd-9d+ 43871 23936  0 10:41 ?        00:00:00 sleep 300
# s68b-82+ 44210 43865  0 Nov21 ?        00:01:50 /usr/local/src/bluemix_jupyter_b
# sbb6-28+ 44237 43628  0 Nov23 ?        00:01:21 /usr/local/src/bluemix_jupyter_b
# sbb6-28+ 44260 43256  0 10:41 ?        00:00:00 sleep 300
# saa7-b0+ 44290 10214  0 10:41 ?        00:00:00 sleep 300
# sc35-f8+ 44316 22041  0 10:41 ?        00:00:00 sleep 300
# root     44391     2  0 03:30 ?        00:00:00 [kworker/25:1]
# root     44392     2  0 03:30 ?        00:00:00 [kworker/25:2]
# s68b-82+ 44653 43692  0 10:41 ?        00:00:00 sleep 300
# s68b-82+ 44707 44210  0 Nov21 ?        00:35:24 /usr/local/src/spark160master/ib
# sbb6-28+ 44855 44237  0 Nov23 ?        00:29:52 /usr/local/src/spark160master/ib
# root     44881     2  0 01:50 ?        00:00:00 [kworker/35:2]
# sdde-ac+ 45178 28061  0 10:41 ?        00:00:00 sleep 300
# s2d2-91+ 45359 15276  0 Nov23 ?        00:00:00 /disk1/ego/3.4/linux-x86_64/etc/
# s2d2-91+ 45361 45359  0 Nov23 ?        00:00:00 bash /usr/local/src/bluemix_jupy
# s2d2-91+ 45362 45359  0 Nov23 ?        00:00:00 /disk1/ego/3.4/linux-x86_64/etc/
# s2d2-91+ 45375 45362  0 Nov23 ?        00:00:02 /bin/bash /usr/local/src/bluemix
# root     45530     2  0 Nov19 ?        00:00:00 [kworker/44:1H]
# root     45607     2  0 10:41 ?        00:00:00 [kworker/17:2]
# root     45608     2  0 10:41 ?        00:00:00 [kworker/19:0]
# root     45609     2  0 10:41 ?        00:00:00 [kworker/20:2]
# root     45610     2  0 10:41 ?        00:00:00 [kworker/20:3]
# s4ea-21+ 45630 46202  0 Nov24 ?        00:01:05 /usr/local/src/bluemix_jupyter_b
# s978-fd+ 45652 16911  0 Nov22 ?        00:01:35 /usr/local/src/bluemix_jupyter_b
# s2d2-91+ 45654 45361  0 Nov23 ?        00:00:44 python /usr/local/src/bluemix_ju
# s853-55+ 45753  5655  0 10:41 ?        00:00:00 sleep 300
# s389-7c+ 45765 15276  0 Nov23 ?        00:00:00 /disk1/ego/3.4/linux-x86_64/etc/
# s389-7c+ 45766 45765  0 Nov23 ?        00:00:00 bash /usr/local/src/bluemix_jupy
# s389-7c+ 45767 45765  0 Nov23 ?        00:00:00 /disk1/ego/3.4/linux-x86_64/etc/
# s389-7c+ 45768 45767  0 Nov23 ?        00:00:02 /bin/bash /usr/local/src/bluemix
# s259-ce+ 45784 15276  0 Nov25 ?        00:00:00 /disk1/ego/3.4/linux-x86_64/etc/
# s259-ce+ 45785 45784  0 Nov25 ?        00:00:00 bash /usr/local/src/bluemix_jupy
# s259-ce+ 45786 45784  0 Nov25 ?        00:00:00 /disk1/ego/3.4/linux-x86_64/etc/
# s259-ce+ 45787 45786  0 Nov25 ?        00:00:01 /bin/bash /usr/local/src/bluemix
# s4ea-21+ 45877 45630  0 Nov24 ?        00:20:04 /usr/local/src/spark160master/ib
# s978-fd+ 45909 45652  0 Nov22 ?        00:30:45 /usr/local/src/spark160master/ib
# root     45921 15276  0 09:02 ?        00:00:00 /disk1/ego/3.4/linux-x86_64/etc/
# root     45922 45921  0 09:02 ?        00:00:01 /bin/bash /usr/local/src/spark16
# s389-7c+ 45975 45766  0 Nov23 ?        00:03:26 python /usr/local/src/bluemix_ju
# s4ea-21+ 45995 15276  0 Nov21 ?        00:00:00 /disk1/ego/3.4/linux-x86_64/etc/
# s4ea-21+ 45996 45995  0 Nov21 ?        00:00:00 bash /usr/local/src/bluemix_jupy
# s4ea-21+ 45997 45995  0 Nov21 ?        00:00:00 /disk1/ego/3.4/linux-x86_64/etc/
# s4ea-21+ 45998 45997  0 Nov21 ?        00:00:03 /bin/bash /usr/local/src/bluemix
# s4ea-21+ 46202 45996  0 Nov21 ?        00:01:38 python /usr/local/src/bluemix_ju
# root     46345     1  0 09:02 ?        00:00:49 /usr/local/src/spark160master/ib
# s259-ce+ 46353 45785  0 Nov25 ?        00:00:27 python /usr/local/src/bluemix_ju
# root     46365     2  0 08:09 ?        00:00:00 [kworker/26:1]
# s259-ce+ 46757 45787  0 10:42 ?        00:00:00 sleep 300
# root     47026 15276  0 09:02 ?        00:00:00 /disk1/ego/3.4/linux-x86_64/etc/
# root     47027 47026  0 09:02 ?        00:00:01 /bin/bash /usr/local/src/spark16
# root     47077     2  0 06:39 ?        00:00:00 [kworker/39:0]
# root     47078     2  0 06:39 ?        00:00:00 [kworker/39:3]
# root     47192     1  1 09:02 ?        00:01:01 /usr/local/src/spark160master/ib
# root     47285     2  0 10:42 ?        00:00:00 [kworker/2:0]
# root     47836     2  0 01:51 ?        00:00:00 [kworker/44:1]
# root     47844     2  0 Nov27 ?        00:00:00 [kworker/28:0]
# root     48245     2  0 10:43 ?        00:00:00 [kworker/u96:0]
# idcuser  48299 18624  0 10:43 ?        00:00:00 sleep 30.000
# s259-ce+ 48316 46353  0 Nov25 ?        00:00:32 /usr/local/src/bluemix_jupyter_b
# root     48422 15279  0 10:43 ?        00:00:00 sleep 10
# root     48544 15280  0 10:43 ?        00:00:00 sleep 20
# root     48579 15281  0 10:43 ?        00:00:00 sleep 10
# dwuser   48600  7074  0 10:43 ?        00:00:00 sleep 10s
# s1a9-ed+ 48612 10168  0 10:43 ?        00:00:00 sleep 300
# s259-ce+ 48663 48316  0 Nov25 ?        00:15:53 /usr/local/src/spark160master/ib
# root     48680 15283  0 10:43 ?        00:00:00 sleep 20
# s389-7c+ 48698 45975  0 Nov23 ?        00:01:21 /usr/local/src/bluemix_jupyter_b
# root     48720 15282  0 10:43 ?        00:00:00 sleep 5
# s1ae-8d+ 48721  9953  0 10:43 ?        00:00:00 sleep 2
# root     48732 45922  0 10:43 ?        00:00:00 sleep 1
# root     48733 47027  0 10:43 ?        00:00:00 sleep 1
# se42-5d+ 48735 41496  0 10:43 ?        00:00:00 sleep 2
# root     48736  3514  0 10:43 ?        00:00:00 sleep 1
# root     48737 29659  0 10:43 ?        00:00:00 sleep 1
# root     48738 32116  0 10:43 ?        00:00:00 sleep 1
# root     48739 29345  0 10:43 ?        00:00:00 sleep 1
# root     48749  3775  0 10:43 ?        00:00:00 /usr/lpp/mmfs/bin/mmksh /usr/lpp
# s389-7c+ 48750 34146  0 10:43 pts/0    00:00:00 ps -ef
# root     48819     2  0 Nov23 ?        00:00:00 [kworker/42:2]
# root     48864     2  0 Nov24 ?        00:00:00 [kworker/1:1H]
# s389-7c+ 48970 48698  0 Nov23 ?        00:10:47 /usr/local/src/spark20master/ibm

# %% [markdown]
# ## Step 4 - Register a Temp Table
# <br>
# SQL works on tables.   Currently we have data in a dataframe, but we have no table identifier for it.   Thus, we want to create a temporary table reference that refers to this dataframe.
# <br>
# <div class="panel-group" id="accordion-4">
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-4" href="#collapse1-4">
#         Hint 1</a>
#       </h4>
#     </div>
#     <div id="collapse1-4" class="panel-collapse collapse">
#       <div class="panel-body">The function is: DataframeObject.createTempView("name_of_table")<br>
# Create a table named "world_bank"<br></div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-4" href="#collapse2-4">
#         Hint 2</a>
#       </h4>
#     </div>
#     <div id="collapse2-4" class="panel-collapse collapse">
#       <div class="panel-body">example1_df.("world_bank")</div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-4" href="#collapse3-4">
#         Advanced Optional 1</a>
#       </h4>
#     </div>
#     <div id="collapse3-4" class="panel-collapse collapse">
#       <div class="panel-body">You'll need to create a [catalog](http://spark.apache.org/docs/latest/api/python/pyspark.sql.html?highlight=catalog#pyspark.sql.SparkSession.catalog) object</div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-4" href="#collapse4-4">
#         Advanced Optional 2</a>
#       </h4>
#     </div>
#     <div id="collapse4-4" class="panel-collapse collapse">
#       <div class="panel-body">Try creating a second temporary table on the same dataframe.   What does <i>listTables()</i> return?</div>
#     </div>
#   </div>
#     <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-4" href="#collapse5-4">
#         Advanced Optional 3</a>
#       </h4>
#     </div>
#     <div id="collapse5-4" class="panel-collapse collapse">
#       <div class="panel-body">Drop the additional temp table.   What does <i>listTables()</i> return?</div>
#     </div>
#   </div>
# </div>

# %%
#Create the table to be referenced via SparkSQL
wbdf = spark.read.json("world_bank.json.gz")
wbdf.createOrReplaceTempView("world_bank")

example1_df.createOrReplaceTempView("world_bank")
example1_df.createOrReplaceTempView("world_bank2")
#Advanced Optional 1
cat = spark.catalog
#Advanced Optional 2
cat.listTables()
#Advanced Optional 2
cat.dropTempView('world_bank2')
cat.listTables()
# Out:
# [Table(name=u'world_bank', database=None, description=None, tableType=u'TEMPORARY', isTemporary=True)]

# %% [markdown]
# ## Step 5 - Writing SQL Statements
# <br>
# Write SQL statements to return two rows from the world_bank table.
# <br>
#  <div class="panel-group" id="accordion-5">
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-5" href="#collapse1-5">
#         Hint 1</a>
#       </h4>
#     </div>
#     <div id="collapse1-5" class="panel-collapse collapse">
#       <div class="panel-body">Use the <i>sql()</i> method on your SparkSession</div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-5" href="#collapse2-5">
#         Hint 2</a>
#       </h4>
#     </div>
#     <div id="collapse2-5" class="panel-collapse collapse">
#       <div class="panel-body">Use <i>limit</i> (i.e. <i>limit 2</i>) within your SQL statement to limit the number of rows returned.   Use <i>show()</i> to display the values.</div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-5" href="#collapse3-5">
#         Hint 3</a>
#       </h4>
#     </div>
#     <div id="collapse3-5" class="panel-collapse collapse">
#       <div class="panel-body">Type:<br>
#       spark.sql("select * from world_bank limit 2").show()<br></div>
#     </div>
#   </div>
# </div>

# %%
#Use SQL to query the table and print the output
q1 = spark.sql("SELECT * FROM world_bank LIMIT 2").select("_id").show()
q1 = spark.sql("SELECT _id as id FROM world_bank LIMIT 2").show()
# Out:
# +--------------------+
# |                 _id|
# +--------------------+
# |[52b213b38594d8a2...|
# |[52b213b38594d8a2...|
# +--------------------+
#
# +--------------------+
# |                  id|
# +--------------------+
# |[52b213b38594d8a2...|
# |[52b213b38594d8a2...|
# +--------------------+

# %% [markdown]
# ### Step 5.1 - Writing SQL Statements
# <br>
# Try writing the next three sections yourself first.   Each hint contains the solution for that section.   We provide this here because this is more SQL than Spark and not everyone is familar with SQL.  Nor is this an SQL class!
# <br><br>
#  <div class="panel-group" id="accordion-51">
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-51" href="#collapse1-51">
#         Hint 1</a>
#       </h4>
#     </div>
#     <div id="collapse1-51" class="panel-collapse collapse">
#       <div class="panel-body">spark.sql("select * from world_bank limit 2").toPandas()</div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-51" href="#collapse2-51">
#         Hint 2</a>
#       </h4>
#     </div>
#     <div id="collapse2-51" class="panel-collapse collapse">
#       <div class="panel-body">spark.sql("select regionname, count(*) as regioncount from world_bank group by regionname order by regioncount desc").toPandas()</div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-51" href="#collapse3-51">
#         Hint 3</a>
#       </h4>
#     </div>
#     <div id="collapse3-51" class="panel-collapse collapse">
#       <div class="panel-body">spark.sql("select sector.Name from world_bank limit 5").toPandas()</div>
#     </div>
#   </div>
# </div>

# %%
#Extra credit, take the DataFrame you created with the two records and convert it into a Pandas DataFrame
q1 = spark.sql("SELECT * FROM world_bank LIMIT 10")
pddf = q1.toPandas()

# %%
# Now calculate a simple count based on a group, for example "regionname".   Return the regionname and a count of the values for that regionname. 
#q1 = spark.sql("SELECT count(id) as cnt, regionname FROM world_bank GROUP BY regionname")
import pyspark.sql.functions as func
wbdf.select(wbdf['id'],wbdf['regionname']).groupby('regionname').agg(func.count('id')).explain(True)


#df.groupBy("department").agg(func.max("age"), func.sum("expense"))


#q1.show()
# Out:
# == Parsed Logical Plan ==
# 'Aggregate ['regionname], [unresolvedalias('regionname, None), count('id) AS count(id)#7076]
# +- Project [id#6106, regionname#6125]
#    +- Relation[_id#6092,approvalfy#6093,board_approval_month#6094,boardapprovaldate#6095,borrower#6096,closingdate#6097,country_namecode#6098,countrycode#6099,countryname#6100,countryshortname#6101,docty#6102,envassesmentcategorycode#6103,grantamt#6104L,ibrdcommamt#6105L,id#6106,idacommamt#6107L,impagency#6108,lendinginstr#6109,lendinginstrtype#6110,lendprojectcost#6111L,majorsector_percent#6112,mjsector_namecode#6113,mjtheme#6114,mjtheme_namecode#6115,... 26 more fields] json
#
# == Analyzed Logical Plan ==
# regionname: string, count(id): bigint
# Aggregate [regionname#6125], [regionname#6125, count(id#6106) AS count(id)#7076L]
# +- Project [id#6106, regionname#6125]
#    +- Relation[_id#6092,approvalfy#6093,board_approval_month#6094,boardapprovaldate#6095,borrower#6096,closingdate#6097,country_namecode#6098,countrycode#6099,countryname#6100,countryshortname#6101,docty#6102,envassesmentcategorycode#6103,grantamt#6104L,ibrdcommamt#6105L,id#6106,idacommamt#6107L,impagency#6108,lendinginstr#6109,lendinginstrtype#6110,lendprojectcost#6111L,majorsector_percent#6112,mjsector_namecode#6113,mjtheme#6114,mjtheme_namecode#6115,... 26 more fields] json
#
# == Optimized Logical Plan ==
# Aggregate [regionname#6125], [regionname#6125, count(id#6106) AS count(id)#7076L]
# +- Project [id#6106, regionname#6125]
#    +- Relation[_id#6092,approvalfy#6093,board_approval_month#6094,boardapprovaldate#6095,borrower#6096,closingdate#6097,country_namecode#6098,countrycode#6099,countryname#6100,countryshortname#6101,docty#6102,envassesmentcategorycode#6103,grantamt#6104L,ibrdcommamt#6105L,id#6106,idacommamt#6107L,impagency#6108,lendinginstr#6109,lendinginstrtype#6110,lendprojectcost#6111L,majorsector_percent#6112,mjsector_namecode#6113,mjtheme#6114,mjtheme_namecode#6115,... 26 more fields] json
#
# == Physical Plan ==
# *HashAggregate(keys=[regionname#6125], functions=[count(id#6106)], output=[regionname#6125, count(id)#7076L])
# +- Exchange hashpartitioning(regionname#6125, 200)
#    +- *HashAggregate(keys=[regionname#6125], functions=[partial_count(id#6106)], output=[regionname#6125, count#7081L])
#       +- *Scan json [id#6106,regionname#6125] Format: JSON, InputPaths: file:/gpfs/global_fs01/sym_shared/YPProdSpark/user/s389-7c57b6f1118293-591ae43264f0/notebook/work..., PartitionFilters: [], PushedFilters: [], ReadSchema: struct<id:string,regionname:string>

# %%
# With JSON data you can reference the nested data.  
# If you look at the Schema above you can see that sector.Name is a nested column.
# Select that column and limit to a reasonable output (say five rows)
q1 = spark.sql("SELECT sector.Name FROM world_bank LIMIT 5")
q1.show()
# Out:
# +--------------------+
# |                Name|
# +--------------------+
# |[Primary educatio...|
# |[Public administr...|
# |[Rural and Inter-...|
# |[Other social ser...|
# |[General industry...|
# +--------------------+

# %% [markdown]
# ## Step 6 - Creating Simple Graphs
# <br>
# Create some simple graphs using the [matplotlib](http://matplotlib.org/1.5.3/index.html) and [numpy](http://www.numpy.org/) libraries
# <br>
# The "%matplotlib inline" statement is used to ensure that graphs are drawn within the notebook instead of popping up as separate windows.
#
# Make SURE you actually run this cell!

# %%
# Load the libraries
# %matplotlib inline 
import matplotlib.pyplot as plt, numpy as np

# %% [markdown]
# ### Step 6.1 - Create the SQL data
# Write the sql statement and look at the data, remember to add <i>.toPandas()</i> for a formatted display. An easier option is to create a variable and set it to the SQL statement.
# #### First create a SQL statement that is a reasonable number of items
# For example, you can count the number of projects (rows) by countryname
# <br>or in other words:
# <br>count(*), countryname from table group by countryname<br><br>
#
#  <div class="panel-group" id="accordion-61">
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-61" href="#collapse1-61">
#         Hint 1</a>
#       </h4>
#     </div>
#     <div id="collapse1-61" class="panel-collapse collapse">
#       <div class="panel-body">Type:<br>
# query = "select count(*) as Count, countryname from world_bank group by countryname"<br></div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-61" href="#collapse2-61">
#         Hint 2</a>
#       </h4>
#     </div>
#     <div id="collapse2-61" class="panel-collapse collapse">
#       <div class="panel-body">Type:<br>
#       chart1_df = spark.sql(query).toPandas()<br>
# print chart1_df<br></div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-61" href="#collapse3-61">
#         Advanced Optional 1</a>
#       </h4>
#     </div>
#     <div id="collapse3-61" class="panel-collapse collapse">
#       <div class="panel-body">Printing the result isn't as nicely formatted.   What command gives you a nicely formatted output?   Use that instead.</div>
#     </div>
#   </div>
# </div>

# %%
# create the query to obtain the number of projects by countryname, save to a variable and print that variable
qstr = "select count(*) as count , countryname from world_bank group by countryname"
pddf = spark.sql(qstr).toPandas()
#Advanced Optional 1
#Advanced Optional 1
from IPython.display import display
display(pddf)
# Out:
#      count                               countryname
# 0       19                     Republic of Indonesia
# 1        2                                South Asia
# 2        4                        Republic of Turkey
# 3        2                                     World
# 4        4              Middle East and North Africa
# 5        1                       Republic of Namibia
# 6        2          Republic of the Marshall Islands
# 7        5                       Republic of Liberia
# 8        1                         Republic of Chile
# 9        2                  Republic of Sierra Leone
# 10       4                       Republic of Burundi
# 11       4                         Republic of Benin
# 12       6                          Republic of Peru
# 13       4                    Republic of Azerbaijan
# 14       7               Hashemite Kingdom of Jordan
# 15       5                         Republic of Haiti
# 16      11                                    Africa
# 17       1                    Republic of Costa Rica
# 18       3               Republic of the Philippines
# 19       8                       Republic of Armenia
# 20       5                         Republic of Niger
# 21       1  Democratic Socialist Republic of Sri Lan
# 22       2            Islamic Republic of Mauritania
# 23       1                      Republic of Kiribati
# 24       4                 Republic of Cote d'Ivoire
# 25       4                           Pacific Islands
# 26       2                      Republic of Cameroon
# 27       1                                    Tuvalu
# 28       8               United Republic of Tanzania
# 29       2                     Republic of Guatemala
# ..     ...                                       ...
# 88       2                        Republic of Kosovo
# 89       7          Lao People's Democratic Republic
# 90       3                      Union of the Comoros
# 91       3                    Republic of Kazakhstan
# 92       2            Plurinational State of Bolivia
# 93       1                       Antigua and Barbuda
# 94       4                         Kingdom of Bhutan
# 95       1                          Kingdom of Tonga
# 96       1                    Republic of Cape Verde
# 97       9              Islamic Republic of Pakistan
# 98       1                    Bosnia and Herzegovina
# 99       5                       Republic of Moldova
# 100     19                People's Republic of China
# 101      1                                   Romania
# 102      3                           Solomon Islands
# 103      2                    Arab Republic of Egypt
# 104     12                                     Nepal
# 105      8                    Republic of Tajikistan
# 106      9                              Burkina Faso
# 107      2  Democratic Republic of Sao Tome and Prin
# 108      4                        Republic of Uganda
# 109      4   Federal Democratic Republic of Ethiopia
# 110      1                      Republic of Zimbabwe
# 111      4                          Republic of Mali
# 112      2        Democratic Republic of Timor-Leste
# 113      2                    Republic of The Gambia
# 114      2                    Republic of Seychelles
# 115     12                        Kingdom of Morocco
# 116     17             Socialist Republic of Vietnam
# 117      4                         Republic of Ghana
#
# [118 rows x 2 columns]

# %% [markdown]
# ### Step 6.2 - Create charts based on the SQL data
# <br>
# Here we wish to create a chart based on the SQL data we just obtained.   Python is an excellent choice when you need to create charts because of the variety and power of the charting libraries available.   The one we are using here is for Pandas.   Specifically the plot() method.   Documentation can be found <a href="http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.plot.html">here</a>.
#
#  <div class="panel-group" id="accordion-62">
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-1" href="#collapse1-62">
#         Hint 1</a>
#       </h4>
#     </div>
#     <div id="collapse1-62" class="panel-collapse collapse">
#       <div class="panel-body">Type:<br>
#       chart1_df.plot(kind='bar', x='countryname', y='Count', figsize=(12, 5))</div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-62" href="#collapse2-62">
#        Advanced Optional 1</a>
#       </h4>
#     </div>
#     <div id="collapse2-62" class="panel-collapse collapse">
#       <div class="panel-body">The table contains too much data.   Change the SQL statement to return a smaller group of values like 30 or 40<br></div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-62" href="#collapse3-62">
#         Advanced Optional 2</a>
#       </h4>
#     </div>
#     <div id="collapse3-62" class="panel-collapse collapse">
#       <div class="panel-body">Looking at the Pandas <i>plot()</i> documentation try other styles of plotting.   Look <a href="http://pandas.pydata.org/pandas-docs/version/0.18.1/visualization.html">here</a> for ideas.<br></div>
#     </div>
#   </div>
# </div>

# %%
# Now take the variable (or same sql statement) and use the method:
# .plot(kind='bar', x='countryname', y='Count', figsize=(12, 5)) to plot a graph

qstr = "select count(*) as count , countryname from world_bank group by countryname order by count desc limit 30"
pddf = spark.sql(qstr).toPandas()
pddf.plot(kind='bar', x='countryname', y='count', figsize=(12, 5))

# %% [markdown]
# ## Step 7 - Creating a DataFrame
# <br>
# Not all data comes with a defined (or derivable) schema like JSON.   Sometimes we have the data first and <b>then</b> need to create a schema for it.<br>
# Try adding a schema to an RDD to create a DataFrame.<br>
# First, you need to create an RDD. This can be done with a loop or as
# seen in the instructor's example, or more simply by assigning values to an array.
# <br><br>

# %%
# Default array defined below. Feel free to change as desired.
array=[[1,1,1],[2,2,2],[3,3,3],["4a","4a","4a"],[5,5,5]]

# %% [markdown]
# ### Step 7.1 - Second, you need to add a schema to the RDD you created in the previous code block.
# Use first the StructField method, following these steps:<br>
# 1- Define your schema columns as a string<br>
# 2- Build the schema object using StructField<br>
# 3- Apply the schema object to the RDD<br>
#
# Note: The cell below is missing some code and will not run properly until you add in some missing parts.
# <br><br>
# <div class="panel-group" id="accordion-71">
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-71" href="#collapse1-71">
#         Hint 1</a>
#       </h4>
#     </div>
#     <div id="collapse1-71" class="panel-collapse collapse">
#       <div class="panel-body">The schema string is simply the space-separated list of column names (i.e. "var1 var2 var3")<br></div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-71" href="#collapse2-71">
#         Hint 2</a>
#       </h4>
#     </div>
#     <div id="collapse2-71" class="panel-collapse collapse">
#       <div class="panel-body">The type should be IntegerType or StringType.   Note that because we are applying this is a loop *everything* will be an Integer or String<br></div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-71" href="#collapse3-71">
#         Hint 3</a>
#       </h4>
#     </div>
#     <div id="collapse3-71" class="panel-collapse collapse">
#       <div class="panel-body">Use the RDD you created above and apply the schema to it i.e.<br>
#       schemaExample = spark.createDataFrame(my_rdd, schema)
#       </div>
#     </div>
#   </div>
#     <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-71" href="#collapse4-71">
#         Hint 4</a>
#       </h4>
#     </div>
#     <div id="collapse4-71" class="panel-collapse collapse">
#       <div class="panel-body">We really don't need to tell you a name to use for your temp table do we?</div>
#     </div>
#   </div>
# </div>

# %%
rdd = spark.sparkContext.parallelize(array)
rdd.take(1)
# Out:
# [[1, 1, 1]]

# %%
from pyspark.sql.types import *

# The schema is encoded in a string. Complete the string below
schemaString = "var1 var2 var3"

# MissingType() should be either StringType() or IntegerType(). Please replace as required.
fields = [StructField(field_name, StringType(), True) for field_name in schemaString.split()]
schema = StructType(fields)
# Apply the schema to the RDD.
schemaExample = spark.createDataFrame(rdd, schema)

# Register the DataFrame as a table. Add table name below as parameter to registerTempTable.
schemaExample.createOrReplaceTempView("junkTable")

# %% [markdown]
# ### Step 7.2 - Thirdly, write some SQL statements to verify that you successfully added a schema to your RDD
# <br>
#  <div class="panel-group" id="accordion-72">
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-72" href="#collapse1-72">
#         Hint 1</a>
#       </h4>
#     </div>
#     <div id="collapse1-72" class="panel-collapse collapse">
#       <div class="panel-body">spark.sql("select * from myRDDTempTable").toPandas()</div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-72" href="#collapse2-72">
#         Advanced Optional 1</a>
#       </h4>
#     </div>
#     <div id="collapse2-72" class="panel-collapse collapse">
#       <div class="panel-body">What is the type is changed to IntegerType (or StringType).   Any change in the results?</div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-72" href="#collapse3-72">
#         Advanced Optional 2</a>
#       </h4>
#     </div>
#     <div id="collapse3-72" class="panel-collapse collapse">
#       <div class="panel-body">Try to do some specific queries on the data (i.e.)<br>
#       spark.sql("select &#42; from myRDDTempTable where var3 > 2").toPandas()<br>
#       Does this work regardless of the data type (i.e. IntegerType or StringType)?<br>
#       What if you change some of the input values (i.e. change all 4s to "4a")<br></div>
#     </div>
#   </div>
# </div>

# %%
#Run some SQL statements on your newly created DataFrame and display the output
a = spark.sql("select var1, var2 from junkTable")
b = spark.sql("select var1, var2 from junkTable")

# %%
c = a.join(b, a.var1 == b.var1, how = 'outer')
c.show()
# Out:
# +----+----+----+----+
# |var1|var2|var1|var2|
# +----+----+----+----+
# |   3|   3|   3|   3|
# |   5|   5|   5|   5|
# |   1|   1|   1|   1|
# |  4a|  4a|  4a|  4a|
# |   2|   2|   2|   2|
# +----+----+----+----+

# %% [markdown]
# ## Step 8
# ### Reading from an external data source
# If you have time, this is a good example to show you how to read from other datasources.  <br><br>
# In a different browser tab, create a dashDB service, add credentials and come back to this notebook. <br>If you are using Data Science Experience, you need to log into Bluemix and create a dashDB instance.   The login and password should be the same as for DSE.<br>
# Each dashDB instance in Bluemix is created with a "GOSALES" set of tables which we can reuse for the purpose of this example. (You can create your own tables if you wish...)<br><br>Replace the Xs in the cell below with proper credentials and verify access to dashDB tables.<br><br>
# You can read from any database that you can connect to through jdbc.  Here is the [documentation](http://spark.apache.org/docs/latest/sql-programming-guide.html#jdbc-to-other-databases)
# <br><br>
#  <div class="panel-group" id="accordion-8">
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-8" href="#collapse1-8">
#         Hint 1</a>
#       </h4>
#     </div>
#     <div id="collapse1-8" class="panel-collapse collapse">
#       <div class="panel-body">To connect to a general dashDB instance:<br>
#       url=""<br>
# user=""<br>
# password=""<br>
# connection="jdbc:db2://" + url + ":50000/BLUDB:user=" + user + ";password=" + password + ";"<br></div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-8" href="#collapse2-8">
#         Advanced Optional</a>
#       </h4>
#     </div>
#     <div id="collapse2-8" class="panel-collapse collapse">
#       <div class="panel-body">Create your own dashDB instance in Bluemix and connect to it</div>
#     </div>
#   </div>
# </div>

# %%
url=""
user=""
password=""
connection="jdbc:db2://" + url + ":50000/BLUDB:user=" + user + ";password=" + password + ";"

salesDF = spark.read.format('jdbc').\
          options(url=connection,\
                  dbtable='GOSALES.BRANCH').load()
salesDF.show()
